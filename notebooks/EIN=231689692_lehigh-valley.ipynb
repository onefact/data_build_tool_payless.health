# %% [markdown]
# # Overview to approach "machine-readable" files
# 1. Try to load it in duckdb
# 2. Try to load it in pandas
# 3. Use command-line tools to determine the encoding
# 4. Re-encode the file
# 5. Repeat to try to load it in duckdb and pandas
# 6. Remove any escape characters using command-line tools
#
# ## Command-line dependencies
# These can be installed using homebrew on Mac OS X:
# ```
# brew install libiconv
# brew install uchardet
# ```

# %%
# Load duckdb, which lets us efficiently load large files
import duckdb

# Load pandas, which lets us manipulate dataframes
import pandas as pd

# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql

# Set configrations on jupysql to directly output data to Pandas and to simplify the output that is printed to the notebook.
# %config SqlMagic.autopandas = True

# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# Allow named parameters (python variables) in SQL cells
# %config SqlMagic.named_parameters=True

# Connect jupysql to DuckDB using a SQLAlchemy-style connection string. Either connect to an in memory DuckDB, or a file backed db.
# %sql duckdb:///:memory:

# %%
# !wget https://www.lvhn.org/sites/default/files/2022-12/231689692_Lehigh_Valley_Hospital_StandardCharges.zip -P /tmp
# Out:
# --2023-08-31 10:14:43--  https://www.lvhn.org/sites/default/files/2022-12/231689692_Lehigh_Valley_Hospital_StandardCharges.zip
# Resolving www.lvhn.org (www.lvhn.org)... 2620:12a:8001::1, 2620:12a:8000::1, 23.185.0.1
# Connecting to www.lvhn.org (www.lvhn.org)|2620:12a:8001::1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37214088 (35M) [application/zip]
# Saving to: ‘/tmp/231689692_Lehigh_Valley_Hospital_StandardCharges.zip’
#
# 231689692_Lehigh_Va 100%[===================>]  35.49M  6.77MB/s    in 5.2s
#
# 2023-08-31 10:14:49 (6.85 MB/s) - ‘/tmp/231689692_Lehigh_Valley_Hospital_StandardCharges.zip’ saved [37214088/37214088]

# %%
# !unzip /tmp/231689692_Lehigh_Valley_Hospital_StandardCharges.zip && mv 231689692_Lehigh_Valley_Hospital_StandardCharges.JSON ~/data/payless_health
# Out:
# Archive:  /tmp/231689692_Lehigh_Valley_Hospital_StandardCharges.zip
#   inflating: 231689692_Lehigh_Valley_Hospital_StandardCharges.JSON

# %%
ls -lh ~/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON
# Out:
# -rw-r--r--  1 me  staff   858M Dec  2  2022 /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON

# %%
# !head /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON
# Out:
# {
# "Standard Charges":[
# {
# "Header":"Lehigh Valley Hospital-Cedar Crest"
# }
# ,
# {
# "Header":"Lehigh Valley Hospital-Muhlenberg"
# }
# ,

# %%
file_path = '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON'

# %%
# %%sql
# SELECT * FROM read_json_auto(:file_path, records=true, maximum_object_size=500000000)
# Out:
# RuntimeError: (duckdb.InvalidInputException) Invalid Input Error: Attempting to execute an unsuccessful or closed pending query result
# Error: Invalid Input Error: Malformed JSON in file "/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON", at byte 1964 in record/value 2: invalid UTF-8 encoding in string.
# [SQL: SELECT * FROM read_json_auto(?, records=true, maximum_object_size=500000000)]
# [parameters: ('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON',)]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# !uchardet /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON
# Out:
# ISO-8859-2

# %%
import io
import chardet
with open(file_path, 'rb') as f:
    result = chardet.detect(f.read(5000000))  # or readline if the file is large

result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
# !file -bI /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON
# Out:
# text/plain; charset=iso-8859-1

# %%
# !iconv -f ISO-8859-1 -t UTF-8 /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON > /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.JSON

# %%
file_path_utf8 = '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.JSON'

# %%
# %%sql
# SELECT * FROM read_json_auto(:file_path_utf8, records=true, maximum_object_size=500000000)
# Out:
# RuntimeError: (duckdb.InvalidInputException) Invalid Input Error: Attempting to execute an unsuccessful or closed pending query result
# Error: Invalid Input Error: Malformed JSON in file "/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.JSON", at byte 878701 in record/value 2: invalid escaped character in string.
# [SQL: SELECT * FROM read_json_auto(?, records=true, maximum_object_size=500000000)]
# [parameters: ('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.JSON',)]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# !od -j 878699 -N 16 -a /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.JSON
# Out:
# 3264153    \   F   I   N   G   E   R  sp   L   S   N   ;  sp   S   U   B
# 3264173

# %% [markdown]
# The offending escape character seems to be a backslash. We can remove it using sed:
# ```
# sed -i '' 's/\\//g' 230831-lehigh-valley.csv
# ```
#
# Or with tr:
# ```
# tr -d '\\' < 230831-lehigh-valley.csv > 230831-lehigh-valley.csv
# ```

# %%
# !tr -d '\\' < /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.JSON > /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON

# %%
# %%sql
# SELECT * FROM read_json_auto('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON', records=true, maximum_object_size=500000000)
# Out:
#                                     Standard Charges  \
# 0  [{'Header': 'Lehigh Valley Hospital-Cedar Cres...
#
#                            Minimum & Maximum Allowed  \
# 0  [{'Payment Type': 'APR DRG', 'Description': 'L...
#
#                                                NCC 4  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                                NCC 5  \
# 0  [{'Header': 'Lehigh Valley Hospital-Cedar Cres...
#
#                                            NCC 5 RCH  \
# 0  [{'Header': 'Lehigh Valley Hospital-Reilly Chi...
#
#                                                NCC 6  \
# 0  [{'Header': 'Lehigh Valley Hospital-Cedar Cres...
#
#                                                NCC 9  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                               NCC 14  \
# 0  [{'Header': 'Lehigh Valley Hospital-Cedar Cres...
#
#                                           NCC 14 RCH  \
# 0  [{'Header': 'Lehigh Valley Hospital-Reilly Chi...
#
#                                               NCC 15  ...  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...  ...
#
#                                              NCC 484  \
# 0  [{'Header': 'Lehigh Valley Hospital-Hecktown O...
#
#                                              NCC 485  \
# 0  [{'Header': 'Lehigh Valley Hospital-Hecktown O...
#
#                                              NCC 486  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                              NCC 494  \
# 0  [{'Payment Type': 'APR DRG', 'Description': 'L...
#
#                                              NCC 499  \
# 0  [{'Payment Type': 'PER DIEM', 'Description': '...
#
#                                              NCC 526  \
# 0  [{'Header': 'Lehigh Valley Hospital-Carbon', '...
#
#                                              NCC 535  \
# 0  [{'Header': 'Lehigh Valley Hospital-Coordinate...
#
#                                              NCC 536  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                              NCC 571  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                              NCC 574
# 0  [{'Payment Type': 'APR DRG', 'Description': 'L...
#
# [1 rows x 83 columns]

# %%
# !head -n 100 /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON
# Out:
# {
# "Standard Charges":[
# {
# "Header":"Lehigh Valley Hospital-Cedar Crest"
# }
# ,
# {
# "Header":"Lehigh Valley Hospital-Muhlenberg"
# }
# ,
# {
# "Header":"Lehigh Valley Hospital-Hecktown Oaks"
# }
# ,
# {
# "Header":"Lehigh Valley Hospital-Reilly Children's Hospital"
# }
# ,
# {
# "Header":"Lehigh Valley Hospital-Tilghman Surgery Center"
# }
# ,
# {
# "Header":"Lehigh Valley Hospital-17th Street"
# }
# ,
# {
# "Header":"Lehigh Valley Hospital-Carbon"
# }
# ,
# {
# "Header":"Lehigh Valley Hospital-Coordinated Health Allentown"
# }
# ,
# {
# "Header":"Lehigh Valley Hospital-Coordinated Health Bethlehem"
# }
# ,
# {
# "Header":"Comprehensive Machine Readable File"
# }
# ,
# {
# "Header":"Date of last Update: 12/15/2022"
# }
# ,
# {
# "DESCRIPTION":"HB MED SURG PRIVATE BED"
# ,
# "BILLING_CODE":"110"
# ,
# "GROSS_CHARGES_IP":"$3,730.00"
# ,
# "GROSS_CHARGES_OP":"N/A"
# ,
# "SELF-PAY_PRICE_IP":"$1,865.00"
# ,
# "SELF-PAY_PRICE_OP":"N/A"
# }
# ,
# {
# "DESCRIPTION":"HB EBOLA PRIVATE"
# ,
# "BILLING_CODE":"110"
# ,
# "GROSS_CHARGES_IP":"$34,485.00"
# ,
# "GROSS_CHARGES_OP":"N/A"
# ,
# "SELF-PAY_PRICE_IP":"$17,242.50"
# ,
# "SELF-PAY_PRICE_OP":"N/A"
# }
# ,
# {
# "DESCRIPTION":"HB OB/GYN  PRIVATE BED"
# ,
# "BILLING_CODE":"112"
# ,
# "GROSS_CHARGES_IP":"$4,795.00"
# ,
# "GROSS_CHARGES_OP":"N/A"
# ,
# "SELF-PAY_PRICE_IP":"$2,397.50"
# ,
# "SELF-PAY_PRICE_OP":"N/A"
# }
# ,
# {
# "DESCRIPTION":"HB OB/GYN LOW LEVEL BED"
# ,
# "BILLING_CODE":"112"
# ,
# "GROSS_CHARGES_IP":"$6,595.00"
# ,
# "GROSS_CHARGES_OP":"N/A"
# ,
# "SELF-PAY_PRICE_IP":"$3,297.50"
# ,
# "SELF-PAY_PRICE_OP":"N/A"

# %%
file_path_iso_8859_1_utf8 = '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON.ISO-8859-1.utf8'

# %%
# %%sql
# SELECT * FROM read_json_auto('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.JSON.ISO-8859-1.utf8', records=true, maximum_object_size=500000000)
# Out:
#                                     Standard Charges  \
# 0  [{'Header': 'Lehigh Valley Hospital-Cedar Cres...
#
#                            Minimum & Maximum Allowed  \
# 0  [{'Payment Type': 'APR DRG', 'Description': 'L...
#
#                                                NCC 4  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                                NCC 5  \
# 0  [{'Header': 'Lehigh Valley Hospital-Cedar Cres...
#
#                                            NCC 5 RCH  \
# 0  [{'Header': 'Lehigh Valley Hospital-Reilly Chi...
#
#                                                NCC 6  \
# 0  [{'Header': 'Lehigh Valley Hospital-Cedar Cres...
#
#                                                NCC 9  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                               NCC 14  \
# 0  [{'Header': 'Lehigh Valley Hospital-Cedar Cres...
#
#                                           NCC 14 RCH  \
# 0  [{'Header': 'Lehigh Valley Hospital-Reilly Chi...
#
#                                               NCC 15  ...  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...  ...
#
#                                              NCC 484  \
# 0  [{'Header': 'Lehigh Valley Hospital-Hecktown O...
#
#                                              NCC 485  \
# 0  [{'Header': 'Lehigh Valley Hospital-Hecktown O...
#
#                                              NCC 486  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                              NCC 494  \
# 0  [{'Payment Type': 'APR DRG', 'Description': 'L...
#
#                                              NCC 499  \
# 0  [{'Payment Type': 'PER DIEM', 'Description': '...
#
#                                              NCC 526  \
# 0  [{'Header': 'Lehigh Valley Hospital-Carbon', '...
#
#                                              NCC 535  \
# 0  [{'Header': 'Lehigh Valley Hospital-Coordinate...
#
#                                              NCC 536  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                              NCC 571  \
# 0  [{'Payment Type': 'MS DRG', 'Description': 'HE...
#
#                                              NCC 574
# 0  [{'Payment Type': 'APR DRG', 'Description': 'L...
#
# [1 rows x 83 columns]

# %% [markdown]
# # Parsing this json with `jq`
#
# 1. Install `jq` with homebrew
# 2. Test it out with `jq . 230831-lehigh-valley.json`
# 3. Use `jq` to extract the `data` array: `jq .data 230831-lehigh-valley.json`
# 4. Use `jq` to extract the `data` array and write it to a file: `jq .data 230831-lehigh-valley.json > 230831-lehigh-valley.json`
# 5. Use `jq.py` (https://github.com/mwilliamson/jq.py) in python to process the 83 columns.
#
# ## Copilot prompt
#
# `jq` command to retrieve column names from the json file:
# ````
# jq .data[0] 230831-lehigh-valley.json
# ````
#
# ## Claude prompt
# ````
# please write a jq command to retrieve the 83 columns names from the json file at /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON where the column names are at the top level and followed by lists.
# ````
#
# Claude response:
# ```
# jq -r 'keys | .[]' /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON
# ```

# %%
keys = !jq -r 'keys | .[]' /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON

# %%
keys
# Out:
# ['Minimum & Maximum Allowed',
#  'NCC 100',
#  'NCC 102',
#  'NCC 105',
#  'NCC 108',
#  'NCC 117',
#  'NCC 128',
#  'NCC 133',
#  'NCC 14',
#  'NCC 14 RCH',
#  'NCC 148',
#  'NCC 15',
#  'NCC 151',
#  'NCC 153',
#  'NCC 157',
#  'NCC 171',
#  'NCC 19',
#  'NCC 26',
#  'NCC 265',
#  'NCC 269',
#  'NCC 269 RCH',
#  'NCC 270',
#  'NCC 270 RCH',
#  'NCC 285',
#  'NCC 286',
#  'NCC 298',
#  'NCC 299',
#  'NCC 31',
#  'NCC 33',
#  'NCC 333',
#  'NCC 350',
#  'NCC 350 MHC',
#  'NCC 359',
#  'NCC 378',
#  'NCC 38',
#  'NCC 4',
#  'NCC 42',
#  'NCC 421',
#  'NCC 421 RCH',
#  'NCC 422',
#  'NCC 422 RCH',
#  'NCC 423',
#  'NCC 429',
#  'NCC 43 HO',
#  'NCC 43 LVH',
#  'NCC 43 MHC',
#  'NCC 43 RCH',
#  'NCC 432',
#  'NCC 44',
#  'NCC 447',
#  'NCC 474',
#  'NCC 475',
#  'NCC 484',
#  'NCC 485',
#  'NCC 486',
#  'NCC 494',
#  'NCC 499',
#  'NCC 5',
#  'NCC 5 RCH',
#  'NCC 52',
#  'NCC 526',
#  'NCC 53',
#  'NCC 535',
#  'NCC 536',
#  'NCC 57',
#  'NCC 571',
#  'NCC 574',
#  'NCC 59',
#  'NCC 6',
#  'NCC 62',
#  'NCC 64',
#  'NCC 66',
#  'NCC 70',
#  'NCC 73',
#  'NCC 77',
#  'NCC 78',
#  'NCC 80',
#  'NCC 80 RCH',
#  'NCC 82',
#  'NCC 87',
#  'NCC 9',
#  'NCC 98',
#  'Standard Charges']

# %% [markdown]
# Claude prompt:
# ```
# one of the top level keys is NCC 14, please select the records for only this key and print the first 10 records in it using `jq`
#
# ```

# %%
# !jq '.["NCC 14"] | .[0:10]' /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON
# Out:
# [
#   {
#     "Header": "Lehigh Valley Hospital-Cedar Crest"
#   },
#   {
#     "Header": "Lehigh Valley Hospital-Muhlenberg"
#   },
#   {
#     "Header": "Lehigh Valley Hospital-Tilghman Surgery Center"
#   },
#   {
#     "Header": "Lehigh Valley Hospital-17th Street"
#   },
#   {
#     "Payment Type": "MS DRG",
#     "Description": "HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC",
#     "Billing Code": "MS001",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$245,068.11",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
#   },
#   {
#     "Payment Type": "MS DRG",
#     "Description": "HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITHOUT MCC",
#     "Billing Code": "MS002",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$146,820.91",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
#   },
#   {
#     "Payment Type": "MS DRG",
#     "Description": "ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRINCIPAL DIAGNOSIS EXCEPT FACE, MOUTH AND NECK WITH MAJOR O.R. PROCEDURES",
#     "Billing Code": "MS003",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$169,723.94",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
#   },
#   {
#     "Payment Type": "MS DRG",
#     "Description": "TRACHEOSTOMY WITH MV >96 HOURS OR PRINCIPAL DIAGNOSIS EXCEPT FACE, MOUTH AND NECK WITHOUT MAJOR O.R. PROCEDURES",
#     "Billing Code": "MS004",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$106,568.47",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
#   },
#   {
#     "Payment Type": "MS DRG",
#     "Description": "LIVER TRANSPLANT WITH MCC OR INTESTINAL TRANSPLANT",
#     "Billing Code": "MS005",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$100,527.57",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
#   },
#   {
#     "Payment Type": "MS DRG",
#     "Description": "LIVER TRANSPLANT WITHOUT MCC",
#     "Billing Code": "MS006",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$43,352.34",
#     "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
#   }
# ]

# %% [markdown]
# Claude prompt:
#
# > write a jq command to retrieve the records that do not have the key "Header" from the file /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON

# %% [markdown]
# next , print records with out "HEADER'" field, or split into 83 files and then skip "Header" field with JQ, then split using the colon into values, then ready for duckdb and box and whisker plot

# %%
# !jq '.["NCC 14"][] | select(."Header" == null)' /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON > /tmp/output.txt

# %%
# !head -n 50 /tmp/output.txt
# Out:
# {
#   "Payment Type": "MS DRG",
#   "Description": "HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC",
#   "Billing Code": "MS001",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$245,068.11",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
# }
# {
#   "Payment Type": "MS DRG",
#   "Description": "HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITHOUT MCC",
#   "Billing Code": "MS002",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$146,820.91",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
# }
# {
#   "Payment Type": "MS DRG",
#   "Description": "ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRINCIPAL DIAGNOSIS EXCEPT FACE, MOUTH AND NECK WITH MAJOR O.R. PROCEDURES",
#   "Billing Code": "MS003",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$169,723.94",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
# }
# {
#   "Payment Type": "MS DRG",
#   "Description": "TRACHEOSTOMY WITH MV >96 HOURS OR PRINCIPAL DIAGNOSIS EXCEPT FACE, MOUTH AND NECK WITHOUT MAJOR O.R. PROCEDURES",
#   "Billing Code": "MS004",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$106,568.47",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
# }
# {
#   "Payment Type": "MS DRG",
#   "Description": "LIVER TRANSPLANT WITH MCC OR INTESTINAL TRANSPLANT",
#   "Billing Code": "MS005",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$100,527.57",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
# }
# {
#   "Payment Type": "MS DRG",
#   "Description": "LIVER TRANSPLANT WITHOUT MCC",
#   "Billing Code": "MS006",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$43,352.34",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
# }
# {
#   "Payment Type": "MS DRG",
#   "Description": "LUNG TRANSPLANT",
#   "Billing Code": "MS007",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_IP": "$94,297.93",
#   "Payor:CAPITAL_BLUE_CROSS_Plan:CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP": "N/A"
# }
# {

# %% [markdown]
# # Generate json files for every one of the 80 headers

# %%
# Run this on every file: 
# !jq '.["NCC 14"][] | select(."Header" == null)' /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON > /tmp/output.txt
import subprocess
from pathlib import Path

file_path = Path('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.ISO-8859-1.utf8.nobackslash.JSON')
output_path = Path('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges')
# output_path.mkdir()

# %%
for key in keys[1:]:
  print(key)
  # get the rows that don't have a header
  temp_file = output_path / f'{key}.tmp'
  with open(temp_file, 'w') as f:
    subprocess.run(['jq', f'.["{key}"][] | select(."Header" == null)', str(file_path)], stdout=f)
  # create valid json
  output_file = output_path / f'{key}.json'
  with open(output_file, 'w') as f:
    subprocess.run(['jq', '-s', '.', temp_file], stdout=f)
  break
# Out:
# NCC 100

# %%
# read output_file with json
import json
with open(output_file) as f:
  data = json.load(f)
  print(data[0:1])
# Out:
# [{'Payment Type': 'APR DRG', 'Description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'Billing Code': 'APR001-1', 'Payor:AETNA_BETTER_HEALTH_Plan:PA_AETNA_BETTER_HEALTH_MEDICAID_IP': '$83,546.60', 'Payor:AETNA_BETTER_HEALTH_Plan:PA_AETNA_BETTER_HEALTH_MEDICAID_OP': 'N/A', 'Payor:AETNA_BETTER_HEALTH_Plan:AETNA_BETTER_HEALTH_KIDS_IP': '$83,546.60', 'Payor:AETNA_BETTER_HEALTH_Plan:AETNA_BETTER_HEALTH_KIDS_OP': 'N/A', 'Payor:AETNA_BETTER_HEALTH_DENTAL_Plan:DENTAL_AETNA_BETTER_HEALTH_MEDICAID_IP': '$83,546.60', 'Payor:AETNA_BETTER_HEALTH_DENTAL_Plan:DENTAL_AETNA_BETTER_HEALTH_MEDICAID_OP': 'N/A', 'Payor:AETNA_BETTER_HEALTH_DENTAL_Plan:DENTAL_AETNA_BETTER_HEALTH_KIDS_IP': '$83,546.60', 'Payor:AETNA_BETTER_HEALTH_DENTAL_Plan:DENTAL_AETNA_BETTER_HEALTH_KIDS_OP': 'N/A'}]

# %% [markdown]
# Claude prompt:
#
# ```
# edit the json records in the data dictionary and split the keys in the records in the following way:
#
# if the key begins with the string Payor, then split the string according to colons (`:`) that appear in the key.
# place the value of the key into a new field with a key of Value
# ```

# %%
import json

def process_lehigh_valley_column_file(file_path, output_path):
  """Split the records for payor into multiple fields separated by colons.
  """
  with open(file_path) as f:
    data = json.load(f)

  for record in data:
    # if 'Payment Type' in record:    
    record['payment_type'] = record.pop('Payment Type')
    record['billing_code'] = record.pop('Billing Code')
    record['description'] = record.pop('Description')
    for key in list(record.keys()):
      if key.startswith('Payor'):
        parts = key.split(':')
        record['payor_name'] = parts[1]
        record['plan_name'] = parts[2]
        record['charge'] = record.pop(key)
        
  with open(output_path, 'w') as f:
    json.dump(data, f)

# %%
process_lehigh_valley_column_file(output_file, output_path / 'lehigh_valley.json')

# %%
from tqdm.notebook import tqdm

# %%
for key in tqdm(keys):
  print(key)
  # get the rows that don't have a header
  temp_file = output_path / f'{key}.tmp'
  with open(temp_file, 'w') as f:
    subprocess.run(['jq', f'.["{key}"][] | select(."Header" == null)', str(file_path)], stdout=f)
  # create valid json
  filtered_file = output_path / f'{key}.json'
  with open(filtered_file, 'w') as f:
    subprocess.run(['jq', '-s', '.', temp_file], stdout=f)
  processed_file = output_path / f'{key}_processed.json'
  process_lehigh_valley_column_file(filtered_file, processed_file)
# Out:
#   0%|          | 0/83 [00:00<?, ?it/s]
# Minimum & Maximum Allowed
# NCC 100
# NCC 102
# NCC 105
# NCC 108
# NCC 117
# NCC 128
# NCC 133
# NCC 14
# NCC 14 RCH
# NCC 148
# NCC 15
# NCC 151
# NCC 153
# NCC 157
# NCC 171
# NCC 19
# NCC 26
# NCC 265
# NCC 269
# NCC 269 RCH
# NCC 270
# NCC 270 RCH
# NCC 285
# NCC 286
# NCC 298
# NCC 299
# NCC 31
# NCC 33
# NCC 333
# NCC 350
# NCC 350 MHC
# NCC 359
# NCC 378
# NCC 38
# NCC 4
# NCC 42
# NCC 421
# NCC 421 RCH
# NCC 422
# NCC 422 RCH
# NCC 423
# NCC 429
# NCC 43 HO
# NCC 43 LVH
# NCC 43 MHC
# NCC 43 RCH
# NCC 432
# NCC 44
# NCC 447
# NCC 474
# NCC 475
# NCC 484
# NCC 485
# NCC 486
# NCC 494
# NCC 499
# NCC 5
# NCC 5 RCH
# NCC 52
# NCC 526
# NCC 53
# NCC 535
# NCC 536
# NCC 57
# NCC 571
# NCC 574
# NCC 59
# NCC 6
# NCC 62
# NCC 64
# NCC 66
# NCC 70
# NCC 73
# NCC 77
# NCC 78
# NCC 80
# NCC 80 RCH
# NCC 82
# NCC 87
# NCC 9
# NCC 98
# Standard Charges

# %%
file_list_subset = [f for f in output_path.glob('*.json') if 'Standard Charges' not in str(f) and 'Minimum & Maximum Allowed' not in str(f)]

for file in tqdm(file_list_subset):
  print(file)
  processed_file = file.with_suffix('.processed.json')
  process_lehigh_valley_column_file(file, processed_file)
# Out:
#   0%|          | 0/82 [00:00<?, ?it/s]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 MHC.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 484.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 105.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 447.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 5.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 59.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 133.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 80.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 38.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 298.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 14.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 148.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 9.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 333.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 299.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 15.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 42.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 108.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 HO.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 574.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 78.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 535.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 4.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 153.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 19.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 485.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 128.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 62.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 RCH.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 359.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 270 RCH.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 53.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 494.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 73.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 350 MHC.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 378.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 285.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 102.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 33.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 64.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 52.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 421 RCH.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 5 RCH.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 270.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 44.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 87.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 421.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 499.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 265.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 526.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 571.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 LVH.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 422.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 475.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 117.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 269.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 286.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/lehigh_valley.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 26.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 70.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 66.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 31.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 100.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 157.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 269 RCH.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 474.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 423.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 14 RCH.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 422 RCH.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 486.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 98.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 77.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 57.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 82.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 80 RCH.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 432.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 536.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 171.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 350.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 429.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 151.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 6.json

# %%
for file in output_path.glob('*.processed.json'):
  print(file)
  with open(file) as f:
    data = json.load(f)
    print(data[0:1])
# Out:
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 82.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'UNITED_HEALTHCARE_COMMUNITY_PLAN_DENTAL_Plan', 'plan_name': 'DENTAL_PA_UHCCP_FOR_FAMILIES_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 494.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'HEALTH_PARTNERS_Plan', 'plan_name': 'KIDZPARTNERS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 19.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'HIGHMARK_WHOLECARE_GATEWAY_DENTAL_Plan', 'plan_name': 'DENTAL_HIGHMARK_WC_GATEWAY_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 350.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'INDEPENDENCE_BLUE_CROSS_MEDICAID_Plan', 'plan_name': 'KEYSTONE_FIRST_COMMUNITY_HEALTHCHOICES_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 105.processed.json
# [{'payment_type': 'PER DIEM', 'billing_code': '0124', 'description': 'INPATIENT PSYCHIATRIC', 'payor_name': 'INTEGRATED_BEHAVIORAL_HEALTH_Plan', 'plan_name': 'INTEGRATED_BEHAVIORAL_HEALTH_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 486.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HEALTH_PARTNERS_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'HEALTH_PARTNERS_MEDICARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 333.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'AMERIHEALTH_VIP_MEDICARE_ADVANTAGE_DENTAL_Plan', 'plan_name': 'DENTAL_AMERIHEALTH_VIP_DUAL_MED_ADV_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 98.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'AETNA_Plan', 'plan_name': 'AETNA_ACCOUNTABLE_CARE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 5.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HORIZON_BCBS_NJ_Plan', 'plan_name': 'HORIZON_BCBS_NJ_PPO_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 117.processed.json
# [{'payment_type': 'PER DIEM', 'billing_code': '0124', 'description': 'INPATIENT PSYCHIATRIC/ADULT', 'payor_name': 'COMMUNITY_CARE_BEHAVIORAL_HEALTH_(CCBHO)_HEALTH_CHOICES_Plan', 'plan_name': 'CCBH_HEALTH_CHOICES_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 102.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'AMERIHEALTH_VIP_MEDICARE_ADVANTAGE_DENTAL_Plan', 'plan_name': 'DENTAL_AMERIHEALTH_VIP_DUAL_MED_ADV_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 14 RCH.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'CAPITAL_BLUE_CROSS_Plan', 'plan_name': 'CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 66.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'IBC_KEYSTONE_65_FOCUS_MEDICARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 73.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'VALLEY_PREFERRED_PO_BOX_1830_Plan', 'plan_name': 'MAGNACARE_VALLEY_PREFERRED_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 4.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'UMR_Plan', 'plan_name': 'UMR_UNITED_HEALTH_INTEGRATED_SERVICES_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 5 RCH.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HORIZON_BCBS_NJ_Plan', 'plan_name': 'HORIZON_BCBS_NJ_PPO_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 574.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'GEISINGER_HEALTHPLAN_FAMILY_PA_Plan', 'plan_name': 'GEISINGER_HEALTHPLAN_FAMILY_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 359.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'AETNA_MEDICARE_ADVANTAGE_DENTAL_Plan', 'plan_name': 'DENTAL_AETNA_DUAL_MEDICARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 MHC.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'AMERIHEALTH_CARITAS_MEDICAID_DENTAL_Plan', 'plan_name': 'DENTAL_AMERIHEALTH_CARITAS_CHC_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 475.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'PA_HEALTH_AND_WELLNESS_Plan', 'plan_name': 'AMBETTER_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 9.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HIGHMARK_BLUE_SHIELD_Plan', 'plan_name': 'HIGHMARK_FIRST_PRIORITY_LIFE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 15.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'NALC_HEALTH_BENEFIT_PLANS_Plan', 'plan_name': 'NALC_HEALTH_BENEFIT_PLANS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 6.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'MERITAIN/WELLNET_Plan', 'plan_name': 'WELLNET_NETWORK_BY_AETNA_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 64.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan', 'plan_name': 'DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 571.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'GEISINGER_Plan', 'plan_name': 'GEISINGER_MARKETPLACE_HMO_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 270 RCH.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'AMERIHEALTH_PA_NJ_Plan', 'plan_name': 'AMERIHEALTH_NJ_NON-HMO_OP_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 422 RCH.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'EMBLEMHEALTH_COMMERCIAL__Plan', 'plan_name': 'EMBLEM_HIP_OON_COMMERCIAL_GENERIC_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 485.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'CAPITAL_BLUE_CROSS_Plan', 'plan_name': 'CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 78.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HIGHMARK_BLUE_SHIELD_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'HIGHMARK_BLUE_SHIELD_FREEDOM_BLUE_MEDICARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 87.processed.json
# [{'payment_type': 'PER DIEM', 'billing_code': '110', 'description': 'HB MED SURG PRIVATE BED', 'payor_name': 'AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan', 'plan_name': 'AMERIHEALTH_ADMIN_VALLEY_PREFERRED_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 421 RCH.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'EMBLEMHEALTH_COMMERCIAL__Plan', 'plan_name': 'EMBLEM_CONNECTICARE_CHOICE_PASSAGE_FLEX_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 484.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HORIZON_BCBS_NJ_Plan', 'plan_name': 'HORIZON_BCBS_NJ_PPO_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 108.processed.json
# [{'payment_type': 'PER DIEM', 'billing_code': '0124', 'description': 'INPATIENT PSYCHIATRIC/ADOLESCENT', 'payor_name': 'MAGELLAN_COMMERCIAL_GENERIC_Plan', 'plan_name': 'MAGELLAN_BEHAVORIAL_HEALTH_PO_BOX_1009_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 100.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'AETNA_BETTER_HEALTH_DENTAL_Plan', 'plan_name': 'DENTAL_AETNA_BETTER_HEALTH_KIDS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 499.processed.json
# [{'payment_type': 'PER DIEM', 'billing_code': '110', 'description': 'HB MED SURG PRIVATE BED', 'payor_name': 'HOMESTEAD_CLAIM_WATCHER_Plan', 'plan_name': 'UHP_MANAGEMENT_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 14.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'CAPITAL_BLUE_CROSS_Plan', 'plan_name': 'CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 171.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HIGHMARK_BLUE_SHIELD_DENTAL_Plan', 'plan_name': 'DENTAL_HIGHMARK_BLUE_SHIELD_KIDS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 70.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HIGHMARK_BLUE_SHIELD_Plan', 'plan_name': 'HIGHMARK_MY_DIRECT_BLUE_EPO_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 80.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'UPMC_MEDICAID_DENTAL_Plan', 'plan_name': 'DENTAL_UPMC_COMMUNITY_HEALTHCHOICES_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 474.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS008', 'description': 'SIMULTANEOUS PANCREAS AND KIDNEY TRANSPLANT', 'payor_name': 'BCBS_BLUE_DISTINCTION_Plan', 'plan_name': 'BCBS_BLUE_DISTINCTION_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 62.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'IBC_KEYSTONE_FIRST_VIP_CHOICE_DUAL_MEDICARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 77.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'UPMC_COMMERCIAL_DENTAL_Plan', 'plan_name': 'DENTAL_UPMC_FOR_KIDS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/lehigh_valley.processed.json
# [{'payor_name': 'AETNA_BETTER_HEALTH_DENTAL_Plan', 'plan_name': 'DENTAL_AETNA_BETTER_HEALTH_KIDS_OP', 'charge': 'N/A', 'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 270.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'INDEPENDENCE_ADMINISTRATORS_Plan', 'plan_name': 'INDEPENDENCE_ADMINISTRATORS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 265.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'UPMC_FOR_LIFE_MEDICARE_ADVANTAGE_DENTAL_Plan', 'plan_name': 'DENTAL_UPMC_FOR_LIFE_DUAL_MED_ADV_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 133.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'UNITED_HEALTHCARE_COMMUNITY_PLAN_DENTAL_Plan', 'plan_name': 'DENTAL_PA_UHC_FOR_KIDS_COMMUNITY_PLAN_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 157.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'AETNA_Plan', 'plan_name': 'AETNA_WHOLE_HEALTH_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 59.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'GEISINGER_MEDICARE_ADVANTAGE_DENTAL__Plan', 'plan_name': 'DENTAL_GEISINGER_GOLD_MED_DUAL_ADV_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 423.processed.json
# [{'payment_type': 'PER DIEM', 'billing_code': '0124', 'description': 'INPATIENT PSYCHIATRIC/ADOLESCENT', 'payor_name': 'UNITED_BEHAVIORAL_HEALTH_Plan', 'plan_name': 'UNITED_BEHAVIORAL_HEALTH_PO_BOX_30757_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 535.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'EMBLEMHEALTH_MEDICARE_ADVANTAGE__Plan', 'plan_name': 'EMBLEMHEALTH_HIP_VIP_DUAL_MED_ADV_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 RCH.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'AMERIHEALTH_CARITAS_MEDICAID_DENTAL_Plan', 'plan_name': 'DENTAL_AMERIHEALTH_CARITAS_CHC_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 447.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'OXFORD_Plan', 'plan_name': 'UHC_OXFORD_SPCL_CONTRACTED_GROUP_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 44.processed.json
# [{'payment_type': 'PER DIEM', 'billing_code': '0124', 'description': 'INPATIENT PSYCHIATRIC/ADOLESCENT', 'payor_name': 'MAGELLAN_HEALTH_CHOICES_(MCO)_Plan', 'plan_name': 'MAGELLAN_HEALTH_CHOICES_MEDICAID_NORTHAMPTON_CNTY_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 422.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'EMBLEMHEALTH_COMMERCIAL_Plan', 'plan_name': 'EMBLEM_HIP_OON_COMMERCIAL_GENERIC_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 151.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'VIBRA_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'VIBRA_MEDICARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 128.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HUMANA_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'HUMANA_MEDICARE_ADVANTAGE_PFFS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 526.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'AMERIHEALTH_CARITAS_MEDICAID_DENTAL_Plan', 'plan_name': 'DENTAL_AMERIHEALTH_CARITAS_CHC_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 26.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'CIGNA_Plan', 'plan_name': 'CIGNA_MVP_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 33.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'GEISINGER_HEALTHPLAN_PA_KIDS_DENTAL_Plan', 'plan_name': 'DENTAL_GEISINGER_HEALTHPLAN_KIDS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 HO.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'AMERIHEALTH_CARITAS_MEDICAID_DENTAL_Plan', 'plan_name': 'DENTAL_AMERIHEALTH_CARITAS_CHC_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 286.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'ALLWELL_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'WELLCARE_BY_ALLWELL_PA_DUAL_MEDICARE_ADV_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 42.processed.json
# [{'payment_type': 'PER DIEM', 'billing_code': '0124', 'description': 'INPATIENT PSYCHIATRIC/ADOLESCENT', 'payor_name': 'MAGELLAN_HEALTH_CHOICES_(MCO)_Plan', 'plan_name': 'MAGELLAN_HEALTH_CHOICES_MEDICAID_LEHIGH_COUNTY_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 57.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'AETNA_MEDICARE_ADVANTAGE_DENTAL_Plan', 'plan_name': 'DENTAL_AETNA_DUAL_MEDICARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 350 MHC.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'INDEPENDENCE_BLUE_CROSS_MEDICAID_Plan', 'plan_name': 'KEYSTONE_FIRST_COMMUNITY_HEALTHCHOICES_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 31.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'VALLEY_PREFERRED_NETWORK_Plan', 'plan_name': 'DH_EVANS_ASSOC_VALLEY_PREFERRED_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 378.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'AMERIHEALTH_CARITAS_MEDICAID_DENTAL_Plan', 'plan_name': 'DENTAL_AMERIHEALTH_CARITAS_CHC_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 432.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'CAPITAL_BLUE_CROSS_Plan', 'plan_name': 'CBC_KEYSTONE_HEALTH_PLAN_CENTRAL_KIDS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 LVH.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'AMERIHEALTH_CARITAS_MEDICAID_DENTAL_Plan', 'plan_name': 'DENTAL_AMERIHEALTH_CARITAS_CHC_MEDICAID_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 299.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'MERITAIN/WELLNET_Plan', 'plan_name': 'WELLNET_NETWORK_BY_AETNA_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 153.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'BLUECARD_OUT_OF_STATE_Plan', 'plan_name': 'BLUECARD-HPN-HIGH_PERFORMANCE_NETWORK_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 52.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HIGHMARK_WHOLECARE_GATEWAY_MEDICARE_ASSURED_DENTAL_Plan', 'plan_name': 'DENTAL_HIGHMARK_WC_GATEWAY_MED_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 269.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'AMERIHEALTH_PA_NJ_Plan', 'plan_name': 'AMERIHEALTH_NJ_HMO_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 536.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'CIGNA_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'CIGNA_MEDICARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 80 RCH.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'UPMC_MEDICAID_DENTAL_Plan', 'plan_name': 'DENTAL_UPMC_COMMUNITY_HEALTHCHOICES_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 429.processed.json
# [{'payment_type': 'CASE RATE', 'billing_code': 'MS650 & REV 0812', 'description': 'KIDNEY TRANSPLANT WITH HEMODIALYSIS WITH MCC WITH CADAVER DONOR', 'payor_name': 'OPTUMHEALTH_COMPLEX_MEDICAL_CARE_Plan', 'plan_name': 'OPTUM_GLOBAL_TRANSPLANT_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 53.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'BLUECARD_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'BLUECARD_DUAL_MEDICARE_ADVANTAGE_BCBS_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 421.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'EMBLEMHEALTH_COMMERCIAL_Plan', 'plan_name': 'EMBLEM_CONNECTICARE_CHOICE_PASSAGE_FLEX_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 38.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HIGHMARK_BLUE_SHIELD_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'HIGHMARK_BS_COMMUNITY_BLUE_PPO_MEDCARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 298.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'HORIZON_BCBS_NJ_Plan', 'plan_name': 'HORIZON_BCBS_NJ_PPO_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 269 RCH.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'AMERIHEALTH_PA_NJ_Plan', 'plan_name': 'AMERIHEALTH_NJ_HMO_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 148.processed.json
# [{'payment_type': 'MS DRG', 'billing_code': 'MS001', 'description': 'HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM WITH MCC', 'payor_name': 'UPMC_FOR_LIFE_MEDICARE_ADVANTAGE_Plan', 'plan_name': 'UPMC_FOR_LIFE_MEDICARE_ADVANTAGE_OP', 'charge': 'N/A'}]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 285.processed.json
# [{'payment_type': 'APR DRG', 'billing_code': 'APR001-1', 'description': 'LIVER TRANSPLANT &/OR INTESTINAL TRANSPLANT', 'payor_name': 'PA_HEALTH_AND_WELLNESS_MEDICAID_DENTAL_Plan', 'plan_name': 'DENTAL_PHW_COMMUNITY_HEALTHCHOICES_MA_OP', 'charge': 'N/A'}]

# %%
# %%sql
# SELECT * FROM read_json_auto('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 64.processed.json')
# Out:
#               payment_type billing_code  \
# 0                   MS DRG        MS001
# 1                   MS DRG        MS002
# 2                   MS DRG        MS003
# 3                   MS DRG        MS004
# 4                   MS DRG        MS005
# ...                    ...          ...
# 13459  NOT SEPARATELY PAID        V2790
# 13460             PER DIEM        90853
# 13461             PER DIEM        90853
# 13462             PER DIEM        90853
# 13463             PER DIEM        90853
#
#                                              description  \
# 0      HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...
# 1      HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...
# 2      ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...
# 3      TRACHEOSTOMY WITH MV >96 HOURS OR PRINCIPAL DI...
# 4      LIVER TRANSPLANT WITH MCC OR INTESTINAL TRANSP...
# ...                                                  ...
# 13459                                  AMNIOTIC MEMBRANE
# 13460     OP PARTIAL HOSPITALIZATION-FULL DAY ADOLESCENT
# 13461      OP PARTIAL HOSPITALIZATION-1/2 DAY ADOLESCENT
# 13462          OP PARTIAL HOSPITALIZATION-FULL DAY ADULT
# 13463           OP PARTIAL HOSPITALIZATION-1/2 DAY ADULT
#
#                                              payor_name  \
# 0      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 1      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 2      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 3      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 4      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# ...                                                 ...
# 13459  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 13460  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 13461  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 13462  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 13463  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
#
#                                     plan_name   charge
# 0      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP      N/A
# 1      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP      N/A
# 2      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP      N/A
# 3      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP      N/A
# 4      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP      N/A
# ...                                       ...      ...
# 13459  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP      N/A
# 13460  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP  $399.00
# 13461  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP  $323.00
# 13462  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP  $399.00
# 13463  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP  $323.00
#
# [13464 rows x 6 columns]

# %%
# %%sql
# SELECT * FROM read_json_auto('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 64.processed.json')
# WHERE charge != 'N/A'
# Out:
#       payment_type billing_code  \
# 0         PER UNIT        10004
# 1         PER UNIT        10005
# 2         PER UNIT        10006
# 3         PER UNIT        10007
# 4         PER UNIT        10008
# ...            ...          ...
# 10921    PER VISIT        V2785
# 10922     PER DIEM        90853
# 10923     PER DIEM        90853
# 10924     PER DIEM        90853
# 10925     PER DIEM        90853
#
#                                           description  \
# 0                          FNA BX W/O IMG GDN EA ADDL
# 1                             FNA BX W/US GDN 1ST LES
# 2                             FNA BX W/US GDN EA ADDL
# 3                          FNA BX W/FLUOR GDN 1ST LES
# 4                          FNA BX W/FLUOR GDN EA ADDL
# ...                                               ...
# 10921                       CORNEAL TISSUE PROCESSING
# 10922  OP PARTIAL HOSPITALIZATION-FULL DAY ADOLESCENT
# 10923   OP PARTIAL HOSPITALIZATION-1/2 DAY ADOLESCENT
# 10924       OP PARTIAL HOSPITALIZATION-FULL DAY ADULT
# 10925        OP PARTIAL HOSPITALIZATION-1/2 DAY ADULT
#
#                                              payor_name  \
# 0      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 1      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 2      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 3      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 4      UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# ...                                                 ...
# 10921  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 10922  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 10923  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 10924  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
# 10925  UNITED_HEALTHCARE_MEDICARE_ADVANTAGE_DENTAL_Plan
#
#                                     plan_name     charge
# 0      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP     $44.14
# 1      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP    $685.07
# 2      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP     $52.03
# 3      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP    $685.07
# 4      DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP     $59.17
# ...                                       ...        ...
# 10921  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP  $3,576.30
# 10922  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP    $399.00
# 10923  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP    $323.00
# 10924  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP    $399.00
# 10925  DENTAL_PA_UHC_DUAL_COMPLETE_MED_ADV_OP    $323.00
#
# [10926 rows x 6 columns]

# %%
# %%sql
# COPY (
# SELECT * FROM read_json_auto('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 64.processed.json')
# WHERE charge != 'N/A'
# ) TO '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 64_processed.parquet' (COMPRESSION ZSTD)
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
from pathlib import Path
output_path = Path('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges')
file_list_subset = [f for f in output_path.glob('*.processed.json') if 'Standard Charges' not in str(f) and 'Minimum & Maximum Allowed' not in str(f)]

# %%
file_list_subset
# Out:
# [PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 82.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 494.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 19.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 350.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 105.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 486.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 333.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 98.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 5.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 117.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 102.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 14 RCH.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 66.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 73.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 4.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 5 RCH.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 574.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 359.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 MHC.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 475.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 9.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 15.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 6.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 64.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 571.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 270 RCH.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 422 RCH.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 485.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 78.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 87.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 421 RCH.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 484.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 108.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 100.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 499.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 14.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 171.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 70.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 80.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 474.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 62.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 77.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/lehigh_valley.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 270.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 265.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 133.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 157.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 59.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 423.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 535.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 RCH.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 447.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 44.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 422.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 151.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 128.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 526.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 26.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 33.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 HO.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 286.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 42.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 57.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 350 MHC.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 31.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 378.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 432.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 LVH.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 299.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 153.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 52.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 269.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 536.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 80 RCH.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 429.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 53.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 421.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 38.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 298.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 269 RCH.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 148.processed.json'),
#  PosixPath('/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 285.processed.json')]

# %%
# execute duckdb query to convert to parquet for every processed file
import duckdb
from tqdm.notebook import tqdm

for file in tqdm(file_list_subset):
  print(file)
  file_path = file.absolute().as_posix()
  file_path_output = file.with_suffix('.parquet').absolute().as_posix()
  duckdb.sql(f"COPY (SELECT * FROM read_json_auto('{file_path}') WHERE charge != 'N/A') TO '{file_path_output}' (COMPRESSION ZSTD)")
# Out:
#   0%|          | 0/82 [00:00<?, ?it/s]
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 82.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 494.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 19.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 350.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 105.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 486.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 333.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 98.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 5.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 117.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 102.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 14 RCH.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 66.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 73.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 4.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 5 RCH.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 574.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 359.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 MHC.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 475.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 9.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 15.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 6.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 64.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 571.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 270 RCH.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 422 RCH.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 485.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 78.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 87.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 421 RCH.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 484.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 108.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 100.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 499.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 14.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 171.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 70.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 80.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 474.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 62.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 77.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/lehigh_valley.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 270.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 265.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 133.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 157.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 59.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 423.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 535.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 RCH.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 447.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 44.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 422.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 151.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 128.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 526.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 26.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 33.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 HO.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 286.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 42.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 57.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 350 MHC.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 31.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 378.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 432.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 43 LVH.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 299.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 153.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 52.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 269.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 536.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 80 RCH.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 429.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 53.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 421.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 38.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 298.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 269 RCH.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 148.processed.json
# /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/NCC 285.processed.json

# %%
# %%sql
# SELECT DISTINCT description FROM '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/*.parquet'
# Out:
#                           description
# 0          FNA BX W/O IMG GDN EA ADDL
# 1            DRAINAGE OF SKIN ABSCESS
# 2          DRAINAGE OF HEMATOMA/FLUID
# 3         PUNCTURE DRAINAGE OF LESION
# 4          DEB SUBQ TISSUE 20 SQ CM/<
# ...                               ...
# 88495       STNT VIABAHN HEP 7X25X120
# 88496    CAGE CENTERPIECE 19X28MM 19C
# 88497  CAGE XPN CMED-L25X32 24-26 0/3
# 88498         DISC MOBI-C 13X15 H6 US
# 88499    STNT MAIN ENDUR II 36X14X103
#
# [88500 rows x 1 columns]

# %%
# %%sql
# SELECT * FROM '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/*.parquet'
# Out:
#        payment_type billing_code                   description  \
# 0          PER UNIT        10004    FNA BX W/O IMG GDN EA ADDL
# 1          PER UNIT        10005       FNA BX W/US GDN 1ST LES
# 2          PER UNIT        10006       FNA BX W/US GDN EA ADDL
# 3          PER UNIT        10021    FNA BX W/O IMG GDN 1ST LES
# 4          PER UNIT        10060      DRAINAGE OF SKIN ABSCESS
# ...             ...          ...                           ...
# 878217     PER UNIT        U0004  COV-19 TEST NON-CDC HGH THRU
# 878218     PER UNIT        U0005  INFEC AGEN DETEC AMPLI PROBE
# 878219     PER UNIT        V2630  ANTER CHAMBER INTRAOCUL LENS
# 878220     PER UNIT        V2632   POST CHMBR INTRAOCULAR LENS
# 878221     PER UNIT        V2785     CORNEAL TISSUE PROCESSING
#
#                                              payor_name  \
# 0                           UPMC_COMMERCIAL_DENTAL_Plan
# 1                           UPMC_COMMERCIAL_DENTAL_Plan
# 2                           UPMC_COMMERCIAL_DENTAL_Plan
# 3                           UPMC_COMMERCIAL_DENTAL_Plan
# 4                           UPMC_COMMERCIAL_DENTAL_Plan
# ...                                                 ...
# 878217  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan
# 878218  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan
# 878219  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan
# 878220  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan
# 878221  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan
#
#                                                 plan_name     charge
# 0                                 DENTAL_UPMC_FOR_KIDS_OP    $617.56
# 1                                 DENTAL_UPMC_FOR_KIDS_OP  $1,511.88
# 2                                 DENTAL_UPMC_FOR_KIDS_OP    $758.50
# 3                                 DENTAL_UPMC_FOR_KIDS_OP    $855.88
# 4                                 DENTAL_UPMC_FOR_KIDS_OP    $494.56
# ...                                                   ...        ...
# 878217  IBC_KEYSTONE_FIRST_VIP_CHOICE_DUAL_MEDICARE_AD...     $75.00
# 878218  IBC_KEYSTONE_FIRST_VIP_CHOICE_DUAL_MEDICARE_AD...     $25.00
# 878219  IBC_KEYSTONE_FIRST_VIP_CHOICE_DUAL_MEDICARE_AD...    $125.10
# 878220  IBC_KEYSTONE_FIRST_VIP_CHOICE_DUAL_MEDICARE_AD...    $125.10
# 878221  IBC_KEYSTONE_FIRST_VIP_CHOICE_DUAL_MEDICARE_AD...  $2,895.10
#
# [878222 rows x 6 columns]

# %%
# %%sql
# SELECT DISTINCT
#   billing_code,
#   payor_name,
#   description,
#   CAST(regexp_replace(charge, '[$,]', '', 'g') AS FLOAT)
# FROM '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/*.parquet'
# Out:
#        billing_code                                        payor_name  \
# 0             10030           HEALTH_PARTNERS_MEDICARE_ADVANTAGE_Plan
# 1             10035           HEALTH_PARTNERS_MEDICARE_ADVANTAGE_Plan
# 2             10080           HEALTH_PARTNERS_MEDICARE_ADVANTAGE_Plan
# 3             10121           HEALTH_PARTNERS_MEDICARE_ADVANTAGE_Plan
# 4             11301           HEALTH_PARTNERS_MEDICARE_ADVANTAGE_Plan
# ...             ...                                               ...
# 790133        C1713  AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
# 790134        C1713  AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
# 790135        C1776  AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
# 790136          270  AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
# 790137        C1776  AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
#
#                           description  \
# 0         GUIDE CATHET FLUID DRAINAGE
# 1         PERQ DEV SOFT TISS 1ST IMAG
# 2          DRAINAGE OF PILONIDAL CYST
# 3                 REMOVE FOREIGN BODY
# 4        SHAVE SKIN LESION 0.6-1.0 CM
# ...                               ...
# 790133          CAPSTONE 12 DEG 13X27
# 790134     SPACER FRA  4A 13MM BRD FF
# 790135  STEM CORAIL COLLARLESS STD 15
# 790136       GRAFT PRECISION 14X26X26
# 790137           STEM FITMORE A SZ 13
#
#         CAST(regexp_replace(charge, '[$,]', '', 'g') AS FLOAT)
# 0                                              691.659973
# 1                                              691.659973
# 2                                              691.659973
# 3                                             1563.880005
# 4                                              199.589996
# ...                                                   ...
# 790133                                       15074.799805
# 790134                                       15098.919922
# 790135                                       11016.200195
# 790136                                       18553.599609
# 790137                                        9566.700195
#
# [790138 rows x 4 columns]

# %%
# %%sql
# SELECT
#   billing_code,
#   description,
#   payor_name,
#   CAST(regexp_replace(charge, '[$,]', '', 'g') AS FLOAT) AS charge,
# FROM '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/*.parquet'
# Out:
#        billing_code                   description  \
# 0             10004    FNA BX W/O IMG GDN EA ADDL
# 1             10005       FNA BX W/US GDN 1ST LES
# 2             10006       FNA BX W/US GDN EA ADDL
# 3             10021    FNA BX W/O IMG GDN 1ST LES
# 4             10060      DRAINAGE OF SKIN ABSCESS
# ...             ...                           ...
# 878217        U0004  COV-19 TEST NON-CDC HGH THRU
# 878218        U0005  INFEC AGEN DETEC AMPLI PROBE
# 878219        V2630  ANTER CHAMBER INTRAOCUL LENS
# 878220        V2632   POST CHMBR INTRAOCULAR LENS
# 878221        V2785     CORNEAL TISSUE PROCESSING
#
#                                              payor_name       charge
# 0                           UPMC_COMMERCIAL_DENTAL_Plan   617.559998
# 1                           UPMC_COMMERCIAL_DENTAL_Plan  1511.880005
# 2                           UPMC_COMMERCIAL_DENTAL_Plan   758.500000
# 3                           UPMC_COMMERCIAL_DENTAL_Plan   855.880005
# 4                           UPMC_COMMERCIAL_DENTAL_Plan   494.559998
# ...                                                 ...          ...
# 878217  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan    75.000000
# 878218  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan    25.000000
# 878219  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan   125.099998
# 878220  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan   125.099998
# 878221  INDEPENDENCE_BLUE_CROSS_MEDICARE_ADVANTAGE_Plan  2895.100098
#
# [878222 rows x 4 columns]

# %%
# %%sql
# COPY (
# SELECT
#   billing_code,
#   description,
#   payor_name,
#   CAST(regexp_replace(charge, '[$,]', '', 'g') AS FLOAT) AS charge,
# FROM '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges/*.parquet'
# ) TO '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.parquet' (COMPRESSION ZSTD)
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# # Create the file for visualization
#
# Prompt:
# ```
# please revise this query for the file '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.parquet' with the following columns `
#
# Copy code
#
# billing_code,
#   description,
#   payor_name, charge
#   ```

# %%
# %%sql
# COPY (
#   WITH max_min_charges AS (
#     SELECT
#       billing_code,
#       description,
#       MIN(charge) AS min_charge,
#       MAX(charge) AS max_charge
#     FROM '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.parquet'
#     GROUP BY billing_code, description
#   ),
#
#   min_max_names AS (
#     SELECT
#       mmc.billing_code,
#       mmc.description,
#       mmc.min_charge,
#       mmc.max_charge,
#       FIRST_VALUE(payor_name) OVER (PARTITION BY mmc.billing_code, mmc.description ORDER BY charge ASC) AS name_minimum,
#       FIRST_VALUE(payor_name) OVER (PARTITION BY mmc.billing_code, mmc.description ORDER BY charge DESC) AS name_maximum
#     FROM max_min_charges mmc
#     JOIN '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges.parquet' sc
#     ON mmc.billing_code = sc.billing_code AND mmc.description = sc.description
#   )
#
#   SELECT DISTINCT
#     billing_code,
#     description,
#     min_charge,
#     max_charge,
#     name_minimum,
#     name_maximum
#   FROM min_max_names
# ) TO '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges_analysis.parquet' (FORMAT 'parquet');
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT * FROM '/Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges_analysis.parquet'
# Out:
#       billing_code                                        description  \
# 0            C1776                            CUP BIMENTUM PRESS 63MM
# 1            27043  HB 27043 EXCISION TUMOR SOFT TISSUE PELVIS&HIP...
# 2            C1713                         SCREW SKYLINE VAR S-D 12MM
# 3            C1713                              SCREW TI POLY 5.00X60
# 4            C1776              LINER PINN MARA NEUT 28X66  121928066
# ...            ...                                                ...
# 90620          272                                  BIT MILLING 2.0MM
# 90621          272                                  FIBER FLEXIVA 550
# 90622          272                      KIT VERTEROPLASTY STABILIT VP
# 90623          272                             SUT LASSO CVD R 45 DEG
# 90624          270                            SUT V-LOC 180 3-0 CV-23
#
#         min_charge   max_charge  \
# 0      5508.100098  6355.500000
# 1      5298.799805  6114.000000
# 2       878.799988  1014.000000
# 3      4406.479980  5084.399902
# 4      4455.419922  5140.870117
# ...            ...          ...
# 90620  1176.459961  2094.590088
# 90621  1661.449951  2958.070068
# 90622  2994.770020  5331.930176
# 90623   736.010010  1310.400024
# 90624   134.270004   239.059998
#
#                                            name_minimum  \
# 0      AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
# 1      AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
# 2      AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
# 3      AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
# 4      AMERIHEALTH_ADMINISTRATORS_VALLEY_PREFERRED_Plan
# ...                                                 ...
# 90620                                        AETNA_Plan
# 90621                                        AETNA_Plan
# 90622                                        AETNA_Plan
# 90623                                        AETNA_Plan
# 90624                                        AETNA_Plan
#
#                        name_maximum
# 0      HOMESTEAD_CLAIM_WATCHER_Plan
# 1      HOMESTEAD_CLAIM_WATCHER_Plan
# 2      HOMESTEAD_CLAIM_WATCHER_Plan
# 3      HOMESTEAD_CLAIM_WATCHER_Plan
# 4      HOMESTEAD_CLAIM_WATCHER_Plan
# ...                             ...
# 90620  HOMESTEAD_CLAIM_WATCHER_Plan
# 90621  HOMESTEAD_CLAIM_WATCHER_Plan
# 90622  HOMESTEAD_CLAIM_WATCHER_Plan
# 90623  HOMESTEAD_CLAIM_WATCHER_Plan
# 90624  HOMESTEAD_CLAIM_WATCHER_Plan
#
# [90625 rows x 6 columns]

# %%
# !ls -lh /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges_analysis.parquet
# Out:
# -rw-r--r--  1 me  staff   2.7M Aug 31 18:12 /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges_analysis.parquet

# %%
# !cp /Users/me/data/payless_health/231689692_Lehigh_Valley_Hospital_StandardCharges_analysis.parquet /Users/me/projects/payless.health/docs/public/data/

# %% [markdown]
# # Create the file for visualization
#
# ````
# meta:
#   title: Hospital Charge Data
#   description: An interactive dashboard of hospital charge data
#
# data:
#   charges: {file: data/231352213_StLukesHospitalBethlehemCampus_standardcharges-analysis.parquet}
#   dd: [
#     { u: 0, v: 0 },
#     { u: 500000, v: 500000 },
#   ]
# hconcat:
# - vconcat:
#   - hconcat:
#     - input: menu
#       label: Insurance_minimum
#       as: $query
#       from: charges
#       column: name_minimum
#     - input: search
#       label: description
#       as: $query
#       from: charges
#       column: description
#       type: contains
#   - vspace: 10
#   - plot:
#     - mark: dot
#       data: {from: charges, filterBy: $query}
#       x: min_charge
#       y: max_charge
#       opacity: 0.1
#       fill: name_minimum
#       r: 2
#     - mark: regressionY
#       data: {from: charges, filterBy: $query}
#       x: min_charge
#       y: max_charge
#     - select: intervalXY
#       as: $query
#       brush: { fillOpacity: 0, stroke: black }
#     - mark: lineY
#       data: { from: dd }
#       x: u
#       y: v
#       stroke: red
#       # curve: monotone-x
#     margins: { left: 60, top: 20, right: 60 }
#     xyDomain: Fixed
#     width: 590
#     height: 350
#     yDomain: [0, 100000]
#     xDomain: [0, 100000]
#     yGrid: true
#     xGrid: true
#   - vspace: 5
#   - input: table
#     from: charges
#     filterBy: $query
#     maxWidth: 700
#     columns:
#       - cpt_drg
#       - record_id
#       - description
#       - min_charge
#       - max_charge
#       - name_minimum
#       - name_maximum
#     width:
#       cpt_drg: 60
#       record_id: 70
#       description: 200
#       min_charge: 90
#       max_charge: 90
#       name_maximum: 120
#       name_minimum: 120
#
# please revise this yaml specification for the file at data/231689692_Lehigh_Valley_Hospital_StandardCharges_analysis.parquet with the columns billing_code, description, payor_name, charge
# ````

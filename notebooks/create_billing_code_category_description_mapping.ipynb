# %%
import pandas as pd

# %%
apr_drg = pd.read_parquet('/Users/me/data/payless_health/3M_APR_DRG_definitions.parquet')

# %%
drg_hcpcs = pd.read_parquet('/Users/me/data/payless_health/drg_hcpcs_codes.parquet')

# %%
apr_drg
# Out:
#      billing_code code_type category  \
# 0             001   APR-DRG     None
# 1             001   APR-DRG     None
# 2             001   APR-DRG     None
# 3             001   APR-DRG     None
# 4             002   APR-DRG     None
# ...           ...       ...      ...
# 1325          952   APR-DRG     None
# 1326          952   APR-DRG     None
# 1327          952   APR-DRG     None
# 1328          955   APR-DRG     None
# 1329          956   APR-DRG     None
#
#                                             description
# 0         Liver transplant and/or intestinal transplant
# 1         Liver transplant and/or intestinal transplant
# 2         Liver transplant and/or intestinal transplant
# 3         Liver transplant and/or intestinal transplant
# 4                          Heart and/or lung transplant
# ...                                                 ...
# 1325  Non-extensive o.r. procedure unrelated to prin...
# 1326  Non-extensive o.r. procedure unrelated to prin...
# 1327  Non-extensive o.r. procedure unrelated to prin...
# 1328  Principal diagnosis invalid as discharge diagn...
# 1329                                        Ungroupable
#
# [1330 rows x 4 columns]

# %%
drg_hcpcs
# Out:
#       billing_code code_type  category  \
# 0              001    MS-DRG      None
# 1              002    MS-DRG      None
# 2              003    MS-DRG      None
# 3              004    MS-DRG      None
# 4              005    MS-DRG      None
# ...            ...       ...       ...
# 18771        99601     HCPCS  Medicine
# 18772        99602     HCPCS  Medicine
# 18773        99605     HCPCS  Medicine
# 18774        99606     HCPCS  Medicine
# 18775        99607     HCPCS  Medicine
#
#                                              description
# 0      Heart transplant or implant of heart assist sy...
# 1      Heart transplant or implant of heart assist sy...
# 2      Ecmo or tracheostomy with mv >96 hours or prin...
# 3      Tracheostomy with mv >96 hours or principal di...
# 4      Liver transplant with mcc or intestinal transp...
# ...                                                  ...
# 18771                          Home infusion/visit 2 hrs
# 18772                        Home infusion each addtl hr
# 18773                            Mtms by pharm np 15 min
# 18774                           Mtms by pharm est 15 min
# 18775                          Mtms by pharm addl 15 min
#
# [18776 rows x 4 columns]

# %%
df = pd.concat([drg_hcpcs, apr_drg])

# %%
df
# Out:
#      billing_code code_type category  \
# 0             001    MS-DRG     None
# 1             002    MS-DRG     None
# 2             003    MS-DRG     None
# 3             004    MS-DRG     None
# 4             005    MS-DRG     None
# ...           ...       ...      ...
# 1325          952   APR-DRG     None
# 1326          952   APR-DRG     None
# 1327          952   APR-DRG     None
# 1328          955   APR-DRG     None
# 1329          956   APR-DRG     None
#
#                                             description
# 0     Heart transplant or implant of heart assist sy...
# 1     Heart transplant or implant of heart assist sy...
# 2     Ecmo or tracheostomy with mv >96 hours or prin...
# 3     Tracheostomy with mv >96 hours or principal di...
# 4     Liver transplant with mcc or intestinal transp...
# ...                                                 ...
# 1325  Non-extensive o.r. procedure unrelated to prin...
# 1326  Non-extensive o.r. procedure unrelated to prin...
# 1327  Non-extensive o.r. procedure unrelated to prin...
# 1328  Principal diagnosis invalid as discharge diagn...
# 1329                                        Ungroupable
#
# [20106 rows x 4 columns]

# %%
df['category'].unique()
# Out:
# array([None, 'Diseases and disorders of the nervous system',
#        'Diseases and disorders of the eye',
#        'Diseases and disorders of the ear, nose, mouth and throat',
#        'Diseases and disorders of the respiratory system',
#        'Diseases and disorders of the circulatory system',
#        'Diseases and disorders of the digestive system',
#        'Diseases and disorders of the hepatobiliary system and pancreas',
#        'Diseases and disorders of the musculoskeletal system and connective tissue',
#        'Diseases and disorders of the skin, subcutaneous tissue and breast',
#        'Endocrine, nutritional and metabolic diseases and disorders',
#        'Diseases and disorders of the kidney and urinary tract',
#        'Diseases and disorders of the male reproductive system',
#        'Diseases and disorders of the female reproductive system',
#        'Pregnancy, childbirth and the puerperium',
#        'Newborns and other neonates with conditions originating in the perinatal period',
#        'Diseases and disorders of blood, blood forming organs and immunological disorders',
#        'Myeloproliferative diseases and disorders, poorly differentiated neoplasms',
#        'Infectious and parasitic diseases, systemic or unspecified sites',
#        'Mental diseases and disorders',
#        'Alcohol or drug use or induced organic mental disorders',
#        'Injuries, poisonings and toxic effects of drugs', 'Burns',
#        'Factors influencing health status and other contacts with health services',
#        'Multiple significant trauma',
#        'Human immunodeficiency virus infections',
#        'Ambulance and Other Transport Services and Supplies',
#        'Matrix for Wound Management', 'Skin Substitute Device',
#        'Medical And Surgical Supplies',
#        'Administrative, Miscellaneous and Investigational',
#        'Dental Procedures', 'Procedures & Professional Services',
#        'Palliative Care Services', 'Alcohol and Drug Abuse Treatment',
#        'Unclassified', 'Drugs Administered Other than Oral Method',
#        'Chemotherapy Drugs', 'MIPS Value Pathways',
#        'Miscellaneous Medical Services', 'Screening Procedures',
#        'Episode of Care', 'Other Services',
#        'Pathology and Laboratory Services', 'Temporary Codes',
#        'Diagnostic Radiology Services',
#        'Temporary National Codes (Non-Medicare)',
#        'National Codes Established for State Medicaid Agencies',
#        'Vision Services', 'Hearing Services', 'Anesthesia',
#        'Emerging technologies, services, procedures, and service paradigms',
#        'Surgery', 'Operating Microscope Procedures', 'Radiology',
#        'Pathology and Laboratory', 'Medicine',
#        'Evaluation and Management'], dtype=object)

# %%
df['category'].value_counts()
# Out:
# Surgery                                                                              6387
# Radiology                                                                            1880
# Pathology and Laboratory                                                             1773
# Medicine                                                                             1564
# Procedures & Professional Services                                                   1308
# Dental Procedures                                                                     924
# Drugs Administered Other than Oral Method                                             739
# Medical And Surgical Supplies                                                         528
# Emerging technologies, services, procedures, and service paradigms                    525
# Temporary National Codes (Non-Medicare)                                               517
# Temporary Codes                                                                       375
# Anesthesia                                                                            337
# Diseases and disorders of the circulatory system                                      241
# Diseases and disorders of the musculoskeletal system and connective tissue            213
# Diseases and disorders of the nervous system                                          191
# Diseases and disorders of the digestive system                                        166
# Chemotherapy Drugs                                                                    157
# Evaluation and Management                                                             155
# Vision Services                                                                       123
# Newborns and other neonates with conditions originating in the perinatal period       119
# Administrative, Miscellaneous and Investigational                                     118
# National Codes Established for State Medicaid Agencies                                114
# Diseases and disorders of the respiratory system                                      113
# Diseases and disorders of the kidney and urinary tract                                106
# Alcohol and Drug Abuse Treatment                                                       88
# Hearing Services                                                                       84
# Diseases and disorders of the hepatobiliary system and pancreas                        76
# Endocrine, nutritional and metabolic diseases and disorders                            74
# Diseases and disorders of the skin, subcutaneous tissue and breast                     72
# Diseases and disorders of the female reproductive system                               69
# Diseases and disorders of the ear, nose, mouth and throat                              69
# Pregnancy, childbirth and the puerperium                                               67
# Other Services                                                                         65
# Injuries, poisonings and toxic effects of drugs                                        60
# Myeloproliferative diseases and disorders, poorly differentiated neoplasms             59
# Mental diseases and disorders                                                          57
# Pathology and Laboratory Services                                                      57
# Screening Procedures                                                                   46
# Infectious and parasitic diseases, systemic or unspecified sites                       45
# Diseases and disorders of the male reproductive system                                 45
# Ambulance and Other Transport Services and Supplies                                    41
# Diseases and disorders of blood, blood forming organs and immunological disorders      39
# Episode of Care                                                                        33
# Factors influencing health status and other contacts with health services              30
# Alcohol or drug use or induced organic mental disorders                                28
# Multiple significant trauma                                                            24
# Human immunodeficiency virus infections                                                22
# Burns                                                                                  22
# Miscellaneous Medical Services                                                         20
# Diseases and disorders of the eye                                                      18
# Matrix for Wound Management                                                            17
# Unclassified                                                                           14
# Palliative Care Services                                                               11
# MIPS Value Pathways                                                                     5
# Diagnostic Radiology Services                                                           3
# Skin Substitute Device                                                                  1
# Operating Microscope Procedures                                                         1
# Name: category, dtype: int64

# %%
df['code_type'].value_counts()
# Out:
# HCPCS      18010
# APR-DRG     1330
# MS-DRG       766
# Name: code_type, dtype: int64

# %%
df.to_parquet('/Users/me/data/payless_health/billing_codes.parquet', index=False)

# %%
df[df['billing_code'] == '77371']
# Out:
#       billing_code code_type   category      description
# 14787        77371     HCPCS  Radiology  Srs multisource

# %%
import pandas as pd

# %%
apr_drg = pd.read_parquet('/Users/me/data/payless_health/3M_APR_DRG_definitions.parquet')

# %%
drg_hcpcs = pd.read_parquet('/Users/me/data/payless_health/drg_hcpcs_codes.parquet')

# %%
apr_drg
# Out:
#     code_type         category  \
# 0     APR-DRG  MDC   : Pre-MDC
# 1     APR-DRG  MDC   : Pre-MDC
# 2     APR-DRG  MDC   : Pre-MDC
# 3     APR-DRG  MDC   : Pre-MDC
# 4     APR-DRG  MDC   : Pre-MDC
# ..        ...              ...
# 329   APR-DRG  MDC   : Pre-MDC
# 330   APR-DRG  MDC   : Pre-MDC
# 331   APR-DRG  MDC   : Pre-MDC
# 332   APR-DRG  MDC   : Pre-MDC
# 333   APR-DRG  MDC   : Pre-MDC
#
#                                            description
# 0        Liver transplant and/or intestinal transplant
# 1                         Heart and/or lung transplant
# 2    Tracheostomy with mv >96 hours with extensive ...
# 3    Tracheostomy with mv >96 hours without extensi...
# 4                                  Pancreas transplant
# ..                                                 ...
# 329  Extensive o.r. procedure unrelated to principa...
# 330  Moderately extensive o.r. procedure unrelated ...
# 331  Non-extensive o.r. procedure unrelated to prin...
# ...

# %%
drg_hcpcs
# Out:
#       billing_code code_type                                      category  \
# 0              001    MS-DRG                               MDC   : Pre-MDC
# 1              002    MS-DRG                               MDC   : Pre-MDC
# 2              003    MS-DRG                               MDC   : Pre-MDC
# 3              004    MS-DRG                               MDC   : Pre-MDC
# 4              005    MS-DRG                               MDC   : Pre-MDC
# ...            ...       ...                                           ...
# 19097        U0001     HCPCS  HCPCS Level II: Coronavirus Diagnostic Panel
# 19098        U0002     HCPCS  HCPCS Level II: Coronavirus Diagnostic Panel
# 19099        U0003     HCPCS  HCPCS Level II: Coronavirus Diagnostic Panel
# 19100        U0004     HCPCS  HCPCS Level II: Coronavirus Diagnostic Panel
# 19101        U0005     HCPCS  HCPCS Level II: Coronavirus Diagnostic Panel
#
#                                              description
# ...

# %%
df = pd.concat([drg_hcpcs, apr_drg])

# %%
df
# Out:
#     billing_code code_type         category  \
# 0            001    MS-DRG  MDC   : Pre-MDC
# 1            002    MS-DRG  MDC   : Pre-MDC
# 2            003    MS-DRG  MDC   : Pre-MDC
# 3            004    MS-DRG  MDC   : Pre-MDC
# 4            005    MS-DRG  MDC   : Pre-MDC
# ..           ...       ...              ...
# 329          NaN   APR-DRG  MDC   : Pre-MDC
# 330          NaN   APR-DRG  MDC   : Pre-MDC
# 331          NaN   APR-DRG  MDC   : Pre-MDC
# 332          NaN   APR-DRG  MDC   : Pre-MDC
# 333          NaN   APR-DRG  MDC   : Pre-MDC
#
#                                            description
# 0    Heart transplant or implant of heart assist sy...
# 1    Heart transplant or implant of heart assist sy...
# 2    Ecmo or tracheostomy with mv >96 hours or prin...
# 3    Tracheostomy with mv >96 hours or principal di...
# 4    Liver transplant with mcc or intestinal transp...
# ..                                                 ...
# ...

# %%
df['category'].unique()
# Out:
# array(['MDC   : Pre-MDC',
#        'MDC 01: Diseases and disorders of the nervous system',
#        'MDC 02: Diseases and disorders of the eye',
#        'MDC 03: Diseases and disorders of the ear, nose, mouth and throat',
#        'MDC 04: Diseases and disorders of the respiratory system',
#        'MDC 05: Diseases and disorders of the circulatory system',
#        'MDC 06: Diseases and disorders of the digestive system',
#        'MDC 07: Diseases and disorders of the hepatobiliary system and pancreas',
#        'MDC 08: Diseases and disorders of the musculoskeletal system and connective tissue',
#        'MDC 09: Diseases and disorders of the skin, subcutaneous tissue and breast',
#        'MDC 10: Endocrine, nutritional and metabolic diseases and disorders',
#        'MDC 11: Diseases and disorders of the kidney and urinary tract',
#        'MDC 12: Diseases and disorders of the male reproductive system',
# ...

# %%
df['category'].value_counts()
# Out:
# HCPCS Level I: Surgery                                6406
# HCPCS Level I: Radiology                              1882
# HCPCS Level I: Pathology and Laboratory               1773
# HCPCS Level I: Medicine                               1571
# HCPCS Level II: Procedures & Professional Services    1312
#                                                       ...
# HCPCS Level II: Diagnostic Radiology Services            3
# HCPCS Level II: Durable Medical Equipment                2
# HCPCS Level I: Operating Microscope Procedures           1
# HCPCS Level II: Enteral and Parenteral Therapy           1
# HCPCS Level II: Skin Substitute Device                   1
# Name: category, Length: 64, dtype: int64

# %%
df['code_type'].value_counts()
# Out:
# HCPCS      18336
# MS-DRG       766
# APR-DRG      334
# Name: code_type, dtype: int64

# %%
df.to_parquet('/Users/me/data/payless_health/billing_codes.parquet', index=False)

# %%
df[df['billing_code'] == '77371']
# Out:
#       billing_code code_type                  category      description
# 14787        77371     HCPCS  HCPCS Level I: Radiology  Srs multisource

# %%
df[df['billing_code'] == '002']
# Out:
#   billing_code code_type         category  \
# 1          002    MS-DRG  MDC   : Pre-MDC
#
#                                          description
# 1  Heart transplant or implant of heart assist sy...

# %% [markdown]
# # Northwell - Lenox Hill Hospital
#
# https://www.northwell.edu/billing-and-insurance/price-estimator-tools
#
# https://www.northwell.edu/sites/northwell.edu/files/machine-readable-files/13-1624070_Lenox%20Hill%20Hospital_standardcharges.json.zip

# %%
# Load duckdb, which lets us efficiently load large files
import duckdb

# Load pandas, which lets us manipulate dataframes
import pandas as pd

# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql

# Set configrations on jupysql to directly output data to Pandas and to simplify the output that is printed to the notebook.
# %config SqlMagic.autopandas = True

# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# Allow named parameters (python variables) in SQL cells
# %config SqlMagic.named_parameters=True

# Connect jupysql to DuckDB using a SQLAlchemy-style connection string. Either connect to an in memory DuckDB, or a file backed db.
# %sql duckdb:///:memory:

# %%
# !wget https://www.northwell.edu/sites/northwell.edu/files/machine-readable-files/13-1624070_Lenox%20Hill%20Hospital_standardcharges.json.zip -P /tmp
# Out:
# --2023-09-26 11:28:12--  https://www.northwell.edu/sites/northwell.edu/files/machine-readable-files/13-1624070_Lenox%20Hill%20Hospital_standardcharges.json.zip
# Resolving www.northwell.edu (www.northwell.edu)... 2606:4700::6811:95b7, 2606:4700::6811:96b7, 104.17.150.183, ...
# Connecting to www.northwell.edu (www.northwell.edu)|2606:4700::6811:95b7|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7195237 (6.9M) [application/zip]
# Saving to: ‘/tmp/13-1624070_Lenox Hill Hospital_standardcharges.json.zip’
#
# 13-1624070_Lenox Hi 100%[===================>]   6.86M  6.25MB/s    in 1.1s
#
# 2023-09-26 11:28:13 (6.25 MB/s) - ‘/tmp/13-1624070_Lenox Hill Hospital_standardcharges.json.zip’ saved [7195237/7195237]

# %%
# !unzip /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges.json.zip -d /tmp
# Out:
# Archive:  /tmp/13-1624070_Lenox Hill Hospital_standardcharges.json.zip
#   inflating: /tmp/13-1624070_Lenox Hill Hospital_StandardCharges.json

# %%
# !head /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges.json
# Out:
# {"Disclaimer": ["This file contains pricing for the following facilities: Lenox Hill Hospital, Lenox Hill Greenwich Village, MEETH"], "Headers": ["Site","Identifier_Code","Billing_Code","Identifier_Description","Charge","Empire Blue Access EPO","Empire Blue Access PPO","Empire Bronze EPO","Empire Bronze Link EPO","Empire Connection EPO","Empire EPO","Empire Federal Employee Program","Empire Gold GEPO","Empire Gold Link EPO","Empire HMO","Empire Indemnity","Empire Platinum Link EPO","Empire PPO","Empire Prism Blue Priority","Empire Silver Link EPO","Empire Silver PPO","EmblemHealth Bronze Plus H.S.A (Small Group)","EmblemHealth Bronze Premier- P (Small Group)","EmblemHealth Bronze Value- P (Small Group)","EmblemHealth Child Health Plus","EmblemHealth ConsumerDirect EPO","EmblemHealth EPO","EmblemHealth EPO Value (EmblemHealth/ConnectiCare Employee Benefit Plan)","EmblemHealth EPO Value (Large Group)","EmblemHealth EPO Value HDHP (Large Group)","EmblemHealth Gold EPO Virtual- N (Small 
# ...

# %%
# %%sql
# SELECT * FROM read_json_auto('/tmp/13-1624070_Lenox Hill Hospital_standardcharges.json', records=false, maximum_object_size=500000000)
# Out:
#                                                 json
# 0  {'Disclaimer': ['This file contains pricing fo...

# %%
# !jq -r 'keys | .[]' /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges.json
# Out:
# Data
# Disclaimer
# Headers

# %%
# !jq '.["Data"] | .[0:10]' /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges.json
# Out:
# [
#   [
#     "LENOX",
#     "",
#     "91038",
#     "Esoph imped funct test > 1hr",
#     "",
#     "3,490.00",
#     "3,490.00",
#     "3,013.00",
#     "3,013.00",
#     "3,013.00",
#     "3,674.00",
#     "3,674.00",
#     "3,343.00",
#     "3,013.00",
#     "3,674.00",
#     "3,674.00",
#     "3,013.00",
#     "3,674.00",
#     "3,674.00",
#     "3,013.00",
#     "3,674.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "5,570.00",
#     "5,570.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
# ...

# %%
# !jq '.["Headers"] | .[]' /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges.json
# Out:
# "Site"
# "Identifier_Code"
# "Billing_Code"
# "Identifier_Description"
# "Charge"
# "Empire Blue Access EPO"
# "Empire Blue Access PPO"
# "Empire Bronze EPO"
# "Empire Bronze Link EPO"
# "Empire Connection EPO"
# "Empire EPO"
# "Empire Federal Employee Program"
# "Empire Gold GEPO"
# "Empire Gold Link EPO"
# "Empire HMO"
# "Empire Indemnity"
# "Empire Platinum Link EPO"
# "Empire PPO"
# "Empire Prism Blue Priority"
# "Empire Silver Link EPO"
# "Empire Silver PPO"
# "EmblemHealth Bronze Plus H.S.A (Small Group)"
# "EmblemHealth Bronze Premier- P (Small Group)"
# "EmblemHealth Bronze Value- P (Small Group)"
# "EmblemHealth Child Health Plus"
# "EmblemHealth ConsumerDirect EPO"
# "EmblemHealth EPO"
# "EmblemHealth EPO Value (EmblemHealth/ConnectiCare Employee Benefit Plan)"
# "EmblemHealth EPO Value (Large Group)"
# "EmblemHealth EPO Value HDHP (Large Group)"
# "EmblemHealth Gold EPO Virtual- N (Small Group)"
# "EmblemHealth Gold PPO-N (Small Group)"
# ...

# %%
# !jq '.["Data"][]' /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges.json  > /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges-data.json

# %%
# !head /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges-data.json
# Out:
# [
#   "LENOX",
#   "",
#   "91038",
#   "Esoph imped funct test > 1hr",
#   "",
#   "3,490.00",
#   "3,490.00",
#   "3,013.00",
#   "3,013.00",

# %%
# !jq -s . /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges-data.json > /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges-data-merged.json

# %%
# !head -n 100 /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges-data-merged.json
# Out:
# [
#   [
#     "LENOX",
#     "",
#     "91038",
#     "Esoph imped funct test > 1hr",
#     "",
#     "3,490.00",
#     "3,490.00",
#     "3,013.00",
#     "3,013.00",
#     "3,013.00",
#     "3,674.00",
#     "3,674.00",
#     "3,343.00",
#     "3,013.00",
#     "3,674.00",
#     "3,674.00",
#     "3,013.00",
#     "3,674.00",
#     "3,674.00",
#     "3,013.00",
#     "3,674.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "5,570.00",
#     "5,570.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
#     "4,623.00",
# ...

# %%
import json

with open('/tmp/13-1624070_Lenox Hill Hospital_standardcharges.json') as f:
    data = json.load(f)

# %%
import csv

with open('/tmp/13-1624070_Lenox Hill Hospital_standardcharges.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(data['Data'])

# %%
# !head /tmp/13-1624070_Lenox\ Hill\ Hospital_standardcharges.csv
# Out:
# LENOX,,91038,Esoph imped funct test > 1hr,,"3,490.00","3,490.00","3,013.00","3,013.00","3,013.00","3,674.00","3,674.00","3,343.00","3,013.00","3,674.00","3,674.00","3,013.00","3,674.00","3,674.00","3,013.00","3,674.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","5,570.00","5,570.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","4,623.00","7,879.00","7,879.00",POC,N/A,N/A,N/A,N/A,N/A,"4,368.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00","5,845.00",POC,POC,POC,POC,POC,POC,POC,"4,625.00","5,570.00","5,570.00","5,570.00","5,570.00","5,570.00","5,570.00","5,570.00","
# ...

# %%
for header in data['Headers']:
    print(f"'{header}': 'VARCHAR',")
# Out:
# 'Site': 'VARCHAR',
# 'Identifier_Code': 'VARCHAR',
# 'Billing_Code': 'VARCHAR',
# 'Identifier_Description': 'VARCHAR',
# 'Charge': 'VARCHAR',
# 'Empire Blue Access EPO': 'VARCHAR',
# 'Empire Blue Access PPO': 'VARCHAR',
# 'Empire Bronze EPO': 'VARCHAR',
# 'Empire Bronze Link EPO': 'VARCHAR',
# 'Empire Connection EPO': 'VARCHAR',
# 'Empire EPO': 'VARCHAR',
# 'Empire Federal Employee Program': 'VARCHAR',
# 'Empire Gold GEPO': 'VARCHAR',
# 'Empire Gold Link EPO': 'VARCHAR',
# 'Empire HMO': 'VARCHAR',
# 'Empire Indemnity': 'VARCHAR',
# 'Empire Platinum Link EPO': 'VARCHAR',
# 'Empire PPO': 'VARCHAR',
# 'Empire Prism Blue Priority': 'VARCHAR',
# 'Empire Silver Link EPO': 'VARCHAR',
# 'Empire Silver PPO': 'VARCHAR',
# 'EmblemHealth Bronze Plus H.S.A (Small Group)': 'VARCHAR',
# 'EmblemHealth Bronze Premier- P (Small Group)': 'VARCHAR',
# 'EmblemHealth Bronze Value- P (Small Group)': 'VARCHAR',
# 'EmblemHealth Child Health Plus': 'VARCHAR',
# 'EmblemHealth ConsumerDirect EPO': 'VARCHAR',
# ...

# %%
# %%sql
# SELECT * FROM read_csv('/tmp/13-1624070_Lenox Hill Hospital_standardcharges.csv',
#                        header=false,
#                        nullstr='N/A',
#                        quote='"',
#                        columns={
#                         'Site': 'VARCHAR',
#                         'Identifier_Code': 'VARCHAR',
#                         'Billing_Code': 'VARCHAR',
#                         'Identifier_Description': 'VARCHAR',
#                         'Charge': 'VARCHAR',
#                         'Empire Blue Access EPO': 'VARCHAR',
#                         'Empire Blue Access PPO': 'VARCHAR',
#                         'Empire Bronze EPO': 'VARCHAR',
#                         'Empire Bronze Link EPO': 'VARCHAR',
#                         'Empire Connection EPO': 'VARCHAR',
#                         'Empire EPO': 'VARCHAR',
#                         'Empire Federal Employee Program': 'VARCHAR',
#                         'Empire Gold GEPO': 'VARCHAR',
#                         'Empire Gold Link EPO': 'VARCHAR',
#                         'Empire HMO': 'VARCHAR',
#                         'Empire Indemnity': 'VARCHAR',
#                         'Empire Platinum Link EPO': 'VARCHAR',
#                         'Empire PPO': 'VARCHAR',
#                         'Empire Prism Blue Priority': 'VARCHAR',
#                         'Empire Silver Link EPO': 'VARCHAR',
#                         'Empire Silver PPO': 'VARCHAR',
#                         'EmblemHealth Bronze Plus H.S.A (Small Group)': 'VARCHAR',
#                         'EmblemHealth Bronze Premier- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Bronze Value- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Child Health Plus': 'VARCHAR',
#                         'EmblemHealth ConsumerDirect EPO': 'VARCHAR',
#                         'EmblemHealth EPO': 'VARCHAR',
#                         'EmblemHealth EPO Value (EmblemHealth/ConnectiCare Employee Benefit Plan)': 'VARCHAR',
#                         'EmblemHealth EPO Value (Large Group)': 'VARCHAR',
#                         'EmblemHealth EPO Value HDHP (Large Group)': 'VARCHAR',
#                         'EmblemHealth Gold EPO Virtual- N (Small Group)': 'VARCHAR',
#                         'EmblemHealth Gold PPO-N (Small Group)': 'VARCHAR',
#                         'EmblemHealth Gold Premier- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Gold Value- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Health Essentials Plus EPO': 'VARCHAR',
#                         'EmblemHealth HIP HMO Preferred (City of NY)': 'VARCHAR',
#                         'EmblemHealth HIP Prime HMO': 'VARCHAR',
#                         'EmblemHealth HIP Prime HMO (Large Group)': 'VARCHAR',
#                         'EmblemHealth HIP Prime POS': 'VARCHAR',
#                         'EmblemHealth HIP Prime POS (City of NY)': 'VARCHAR',
#                         'EmblemHealth HIP Prime PPO (Large Group)': 'VARCHAR',
#                         'EmblemHealth HIP Select PPO (Large Group)': 'VARCHAR',
#                         'EmblemHealth HIPaccessI': 'VARCHAR',
#                         'EmblemHealth HIPaccessII': 'VARCHAR',
#                         'EmblemHealth HMO Plus': 'VARCHAR',
#                         'EmblemHealth HMO Preferred Plus': 'VARCHAR',
#                         'EmblemHealth InBalance EPO': 'VARCHAR',
#                         'EmblemHealth Platinum PPO-N (Small Group)': 'VARCHAR',
#                         'EmblemHealth Platinum Premier- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Platinum Value- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth PPO Value (Large Group)': 'VARCHAR',
#                         'EmblemHealth Silver Plus H.S.A (Small Group)': 'VARCHAR',
#                         'EmblemHealth Silver Premier- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Silver Value- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Vytra HMO (City of NY)': 'VARCHAR',
#                         'Magna Guardian PPO': 'VARCHAR',
#                         'MagnaCare PPO': 'VARCHAR',
#                         'MagnaCare Standard PPO': 'VARCHAR',
#                         'MVP BasiCare PPO': 'VARCHAR',
#                         'MVP HMO': 'VARCHAR',
#                         'MVP Premier': 'VARCHAR',
#                         'MVP Premier Plus': 'VARCHAR',
#                         'MVP Student Health Plan': 'VARCHAR',
#                         'Northwell Direct Commercial Network': 'VARCHAR',
#                         'Aetna Choice POS': 'VARCHAR',
#                         'Aetna Choice POS II': 'VARCHAR',
#                         'Aetna Elect Choice': 'VARCHAR',
#                         'Aetna Health Network Only': 'VARCHAR',
#                         'Aetna Health Network Option': 'VARCHAR',
#                         'Aetna HMO': 'VARCHAR',
#                         'Aetna Limited Benefits Insurance Plan': 'VARCHAR',
#                         'Aetna Managed Choice POS': 'VARCHAR',
#                         'Aetna Meritain PPO': 'VARCHAR',
#                         'Aetna Open Access Aetna Select': 'VARCHAR',
#                         'Aetna Open Access Elect Choice': 'VARCHAR',
#                         'Aetna Open Access HMO': 'VARCHAR',
#                         'Aetna Open Access Managed Choice': 'VARCHAR',
#                         'Aetna Open Choice PPO': 'VARCHAR',
#                         'Aetna Premier Care Network': 'VARCHAR',
#                         'Aetna Quality Point-of-Service (QPOS)': 'VARCHAR',
#                         'Aetna Select': 'VARCHAR',
#                         'Aetna Signature Administrators': 'VARCHAR',
#                         'Aetna Traditional Choice': 'VARCHAR',
#                         'Aetna Value Performance Network': 'VARCHAR',
#                         'Aetna Voluntary Group Medical Plan (Indemnity)': 'VARCHAR',
#                         'Cigna HMO/POS Open Access': 'VARCHAR',
#                         'Cigna Network Open Access': 'VARCHAR',
#                         'Cigna Network/Network POS': 'VARCHAR',
#                         'Cigna Open Access Plus': 'VARCHAR',
#                         'Cigna Open Access Plus/PlusIN Network': 'VARCHAR',
#                         'Cigna Plus Oscar (Cigna+Oscar) LocalPlus': 'VARCHAR',
#                         'Cigna Plus Oscar (Cigna+Oscar) Open Access Plus': 'VARCHAR',
#                         'Cigna PPO/EPO': 'VARCHAR',
#                         'ConnectiCare Bridge EPO': 'VARCHAR',
#                         'ConnectiCare Choice EPO/POS': 'VARCHAR',
#                         'ConnectiCare Choice HMO/POS': 'VARCHAR',
#                         'ConnectiCare Compass Choice EPO': 'VARCHAR',
#                         'ConnectiCare Flex POS': 'VARCHAR',
#                         'ConnectiCare Passage EPO/POS': 'VARCHAR',
#                         'ConnectiCare Passage HMO/POS': 'VARCHAR',
#                         'Connecticare PPO': 'VARCHAR',
#                         'EmblemHealth Bridge ASO': 'VARCHAR',
#                         'EmblemHealth ConsumerDirect PPO': 'VARCHAR',
#                         'EmblemHealth DC37 Med-Team (New York City Plan)': 'VARCHAR',
#                         'EmblemHealth Federal Employee Benefit Plan EPO': 'VARCHAR',
#                         'EmblemHealth GHI CBP Plan (New York City Plan)': 'VARCHAR',
#                         'EmblemHealth GHI HMO (City of NY)': 'VARCHAR',
#                         'EmblemHealth InBalance PPO': 'VARCHAR',
#                         'EmblemHealth Network Access Plan': 'VARCHAR',
#                         'EmblemHealth PPO': 'VARCHAR',
#                         'EmblemHealth PPO Value (EmblemHealth/ConnectiCare Employee Benefit Plan)': 'VARCHAR',
#                         'EmblemHealth PPO Value (Large Group-GHI)': 'VARCHAR',
#                         '1199 SEIU Greater New York Benefit Fund': 'VARCHAR',
#                         '1199 SEIU National Benefit Fund': 'VARCHAR',
#                         '1199 SEIU National Benefit Fund for Home Care Employees': 'VARCHAR',
#                         'Oxford Freedom HMO': 'VARCHAR',
#                         'Oxford Liberty HMO': 'VARCHAR',
#                         'Oxford PPO': 'VARCHAR',
#                         'United HMO': 'VARCHAR',
#                         'United PPO': 'VARCHAR',
#                         'Healthfirst Essential Plan 1': 'VARCHAR',
#                         'Healthfirst Essential Plan 2': 'VARCHAR',
#                         'EmblemHealth Bronze (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Bronze Premier-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Bronze Value-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Catatrophic (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth EPO Value (Large Group-Exch)': 'VARCHAR',
#                         'EmblemHealth EPO Value HDHP (Large Group-Exch)': 'VARCHAR',
#                         'EmblemHealth Gold (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Gold Premier-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Gold Value (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Gold Value-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth HMO Plus (Large Group)': 'VARCHAR',
#                         'EmblemHealth Platinum (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Platinum Premier-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Platinum Value-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth PPO Value (Large Group-Exch)': 'VARCHAR',
#                         'EmblemHealth Silver (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver CSR 1 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver CSR 2 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver CSR 3 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Premier-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Silver Value (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Value CSR 1 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Value CSR 2 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Value CSR 3 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Value-S (Small Group)': 'VARCHAR',
#                         'Empire Gold EPO': 'VARCHAR',
#                         'Empire Gold PPO': 'VARCHAR',
#                         'Empire Platinum EPO': 'VARCHAR',
#                         'Empire Platinum PPO': 'VARCHAR',
#                         'Empire Silver EPO': 'VARCHAR',
#                         'Healthfirst Bronze Leaf Plan': 'VARCHAR',
#                         'Healthfirst Bronze Leaf Premier': 'VARCHAR',
#                         'Healthfirst Bronze Pro Plan': 'VARCHAR',
#                         'Healthfirst Bronze Pro Plus Plan': 'VARCHAR',
#                         'Healthfirst Gold Leaf Plan': 'VARCHAR',
#                         'Healthfirst Gold Leaf Premier': 'VARCHAR',
#                         'Healthfirst Gold Pro Plan': 'VARCHAR',
#                         'Healthfirst Gold Pro Plus Plan': 'VARCHAR',
#                         'Healthfirst Green Leaf Plan': 'VARCHAR',
#                         'Healthfirst Platinum Leaf Plan': 'VARCHAR',
#                         'Healthfirst Platinum Leaf Premier': 'VARCHAR',
#                         'Healthfirst Platinum Pro Plan': 'VARCHAR',
#                         'Healthfirst Platinum Pro Plus Plan': 'VARCHAR',
#                         'Healthfirst Silver Leaf Plan': 'VARCHAR',
#                         'Healthfirst Silver Leaf Premier': 'VARCHAR',
#                         'Healthfirst Silver Pro Plan': 'VARCHAR',
#                         'Healthfirst Silver Pro Plus Plan': 'VARCHAR',
#                         'United - Exchange': 'VARCHAR',
#                         'EmblemHealth Essential Plan 1 (BHP)': 'VARCHAR',
#                         'EmblemHealth Essential Plan 1 Plus': 'VARCHAR',
#                         'EmblemHealth Essential Plan 2': 'VARCHAR',
#                         'EmblemHealth Essential Plan 2 Plus': 'VARCHAR',
#                         'Empire Healthplus Essential Plan': 'VARCHAR',
#                         'Fidelis Care Essential Plan 1': 'VARCHAR',
#                         'Fidelis Care Essential Plan 2': 'VARCHAR',
#                         'United - Essential 1&2': 'VARCHAR',
#                         'Fidelis Care Bronze': 'VARCHAR',
#                         'Fidelis Care Catastrophic': 'VARCHAR',
#                         'Fidelis Care Gold ': 'VARCHAR',
#                         'Fidelis Care Platinum': 'VARCHAR',
#                         'Fidelis Care Silver': 'VARCHAR',
#                         'Fidelis Care Silver (100-150)': 'VARCHAR',
#                         'Fidelis Care Silver (150-200)': 'VARCHAR',
#                         'Fidelis Care Silver (200-250)': 'VARCHAR',
#                         'Affinity Child Health Plus': 'VARCHAR',
#                         'Affinity Enriched Plan (HARP)': 'VARCHAR',
#                         'Affinity Medicaid': 'VARCHAR',
#                         'EmblemHealth Enhanced Care': 'VARCHAR',
#                         'EmblemHealth Enhanced Care Plus': 'VARCHAR',
#                         'EmblemHealth Essential Plan 3': 'VARCHAR',
#                         'EmblemHealth Essential Plan 4': 'VARCHAR',
#                         'Empire Healthplus Child Health Plus': 'VARCHAR',
#                         'Empire Healthplus HARP': 'VARCHAR',
#                         'Empire Healthplus Medicaid': 'VARCHAR',
#                         'Empire Healthplus MLTC': 'VARCHAR',
#                         'Fidelis Care at Home (MLTC)': 'VARCHAR',
#                         'Fidelis Care Essential Plan 3': 'VARCHAR',
#                         'Fidelis Care Essential Plan 4': 'VARCHAR',
#                         'Fidelis Child Health Plus': 'VARCHAR',
#                         'Fidelis HealthierLife (HARP)': 'VARCHAR',
#                         'Fidelis Medicaid Managed Care': 'VARCHAR',
#                         'Fidelis Medicaid Managed Care - Restricted': 'VARCHAR',
#                         'Healthfirst Child Health Plus': 'VARCHAR',
#                         'Healthfirst Essential Plan 3': 'VARCHAR',
#                         'Healthfirst Essential Plan 4': 'VARCHAR',
#                         'Healthfirst Medicaid': 'VARCHAR',
#                         'Healthfirst Personal Wellness Plan (PWP) HARP': 'VARCHAR',
#                         'Metroplus Child Health Plus': 'VARCHAR',
#                         'Metroplus HIV Special Needs Plan': 'VARCHAR',
#                         'Metroplus Medicaid': 'VARCHAR',
#                         'United - Essential 3&4': 'VARCHAR',
#                         'United Medicaid': 'VARCHAR',
#                         'Affinity Essential Plan 1-4': 'VARCHAR',
#                         'Metroplus HARP and Essential Plans  1-4': 'VARCHAR',
#                         'Metroplus Exchange': 'VARCHAR',
#                         'Metroplus Gold': 'VARCHAR',
#                         'Metroplus Gold Care 1': 'VARCHAR',
#                         'Metroplus Gold Care 2': 'VARCHAR',
#                         'Aetna Medicare HMO': 'VARCHAR',
#                         'Aetna Medicare Open Access': 'VARCHAR',
#                         'Aetna Medicare PPO': 'VARCHAR',
#                         'EmblemHealth Group Access Rx PPO': 'VARCHAR',
#                         'EmblemHealth VIP Dual (HMO D-SNP)': 'VARCHAR',
#                         'EmblemHealth VIP Dual Select (HMO D-SNP)': 'VARCHAR',
#                         'EmblemHealth VIP Essential (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Go (HMO-POS)': 'VARCHAR',
#                         'EmblemHealth VIP Gold (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Gold Plus (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Part B Saver (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Passport (HMO) ': 'VARCHAR',
#                         'EmblemHealth VIP Passport NYC (HMO) ': 'VARCHAR',
#                         'EmblemHealth VIP Premier (HMO) (Group Plan)': 'VARCHAR',
#                         'EmblemHealth VIP Rx Carve-Out (HMO) (Group Plan)': 'VARCHAR',
#                         'EmblemHealth VIP Rx Saver (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Solutions (HMO D-SNP)': 'VARCHAR',
#                         'EmblemHealth VIP Value (HMO)': 'VARCHAR',
#                         'Empire MediBlue Access PPO': 'VARCHAR',
#                         'Empire MediBlue Dual Advantage HMO D-SNP': 'VARCHAR',
#                         'Empire MediBlue Dual Advantage Select HMO D-SNP': 'VARCHAR',
#                         'Empire MediBlue Freedom PPO': 'VARCHAR',
#                         'Empire MediBlue HealthPlus Dual Connect': 'VARCHAR',
#                         'Empire MediBlue HealthPlus Dual Plus': 'VARCHAR',
#                         'Empire MediBlue HealthPlus HMO': 'VARCHAR',
#                         'Empire MediBlue HealthPlus Select HMO': 'VARCHAR',
#                         'Empire MediBlue HMO': 'VARCHAR',
#                         'Empire MediBlue HMO (Plus, Service, Choice)': 'VARCHAR',
#                         'Empire MediBlue HMO (Select, Extra Select, Service Select)': 'VARCHAR',
#                         'Empire NYC Medicare Advantage Plus': 'VARCHAR',
#                         'Fidelis Dual Advantage (HMO SNP)': 'VARCHAR',
#                         'Fidelis Dual Advantage Flex (HMO SNP)': 'VARCHAR',
#                         'Fidelis Medicaid Advantage Plus (HMO SNP)': 'VARCHAR',
#                         'Fidelis Medicare Advantage $0 Premium (HMO)': 'VARCHAR',
#                         'Fidelis Medicare Advantage Flex Plan (HMO POS)': 'VARCHAR',
#                         'Fidelis Medicare Advantage Without RX (HMO POS)': 'VARCHAR',
#                         'Healthfirst 65 Plus Plan HMO': 'VARCHAR',
#                         'Healthfirst AbsoluteCare FIDA Plan': 'VARCHAR',
#                         'Healthfirst AssuredCare HMO SNP': 'VARCHAR',
#                         'Healthfirst CompleteCare HMO SNP': 'VARCHAR',
#                         'Healthfirst Coordinated Benefits Plan HMO': 'VARCHAR',
#                         'Healthfirst Increased Benefits Plan HMO': 'VARCHAR',
#                         'Healthfirst Life Improvement Plan HMO SNP': 'VARCHAR',
#                         'Healthfirst Mount Sinai Select HMO': 'VARCHAR',
#                         'Healthfirst Senior Health Partners (SHP)': 'VARCHAR',
#                         'HIP Medicare PPO': 'VARCHAR',
#                         'Humana Medicare HMO': 'VARCHAR',
#                         'Humana Medicare PPO': 'VARCHAR',
#                         'Metroplus FIDA': 'VARCHAR',
#                         'Metroplus Medicare Advantage': 'VARCHAR',
#                         'Oxford Medicare': 'VARCHAR',
#                         'United Medicare': 'VARCHAR',
#                         'Wellcare Medicare Advantage': 'VARCHAR',
#                         'De-identified Maximum': 'VARCHAR',
#                         'De-identified Minimum': 'VARCHAR',
#                         'Discounted Cash Price': 'VARCHAR',
#                        }
# )
# LIMIT 10;
# Out:
#     Site Identifier_Code  Billing_Code  \
# 0  LENOX                         91038
# 1  LENOX                         91110
# 2  LENOX                         92018
# 3  LENOX                         93454
# 4  LENOX                         93582
# 5  LENOX                         93653
# 6  LENOX                         93654
# 7  LENOX                  APR DRG 0011
# 8  LENOX                  APR DRG 0012
# 9  LENOX                  APR DRG 0022
#
#                         Identifier_Description Charge Empire Blue Access EPO  \
# 0                 Esoph imped funct test > 1hr                      3,490.00
# 1                  Gi trc img intral esoph-ile                      3,490.00
# 2                     New eye exam & treatment                      3,490.00
# 3                    Coronary artery angio s&i                     20,038.00
# 4                   Perq transcath closure pda                     10,469.00
# ...

# %%
# %%sql
# COPY (
# SELECT * FROM read_csv('/tmp/13-1624070_Lenox Hill Hospital_standardcharges.csv',
#                        header=false,
#                        nullstr='N/A',
#                        quote='"',
#                        columns={
#                         'Site': 'VARCHAR',
#                         'Identifier_Code': 'VARCHAR',
#                         'Billing_Code': 'VARCHAR',
#                         'Identifier_Description': 'VARCHAR',
#                         'Charge': 'VARCHAR',
#                         'Empire Blue Access EPO': 'VARCHAR',
#                         'Empire Blue Access PPO': 'VARCHAR',
#                         'Empire Bronze EPO': 'VARCHAR',
#                         'Empire Bronze Link EPO': 'VARCHAR',
#                         'Empire Connection EPO': 'VARCHAR',
#                         'Empire EPO': 'VARCHAR',
#                         'Empire Federal Employee Program': 'VARCHAR',
#                         'Empire Gold GEPO': 'VARCHAR',
#                         'Empire Gold Link EPO': 'VARCHAR',
#                         'Empire HMO': 'VARCHAR',
#                         'Empire Indemnity': 'VARCHAR',
#                         'Empire Platinum Link EPO': 'VARCHAR',
#                         'Empire PPO': 'VARCHAR',
#                         'Empire Prism Blue Priority': 'VARCHAR',
#                         'Empire Silver Link EPO': 'VARCHAR',
#                         'Empire Silver PPO': 'VARCHAR',
#                         'EmblemHealth Bronze Plus H.S.A (Small Group)': 'VARCHAR',
#                         'EmblemHealth Bronze Premier- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Bronze Value- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Child Health Plus': 'VARCHAR',
#                         'EmblemHealth ConsumerDirect EPO': 'VARCHAR',
#                         'EmblemHealth EPO': 'VARCHAR',
#                         'EmblemHealth EPO Value (EmblemHealth/ConnectiCare Employee Benefit Plan)': 'VARCHAR',
#                         'EmblemHealth EPO Value (Large Group)': 'VARCHAR',
#                         'EmblemHealth EPO Value HDHP (Large Group)': 'VARCHAR',
#                         'EmblemHealth Gold EPO Virtual- N (Small Group)': 'VARCHAR',
#                         'EmblemHealth Gold PPO-N (Small Group)': 'VARCHAR',
#                         'EmblemHealth Gold Premier- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Gold Value- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Health Essentials Plus EPO': 'VARCHAR',
#                         'EmblemHealth HIP HMO Preferred (City of NY)': 'VARCHAR',
#                         'EmblemHealth HIP Prime HMO': 'VARCHAR',
#                         'EmblemHealth HIP Prime HMO (Large Group)': 'VARCHAR',
#                         'EmblemHealth HIP Prime POS': 'VARCHAR',
#                         'EmblemHealth HIP Prime POS (City of NY)': 'VARCHAR',
#                         'EmblemHealth HIP Prime PPO (Large Group)': 'VARCHAR',
#                         'EmblemHealth HIP Select PPO (Large Group)': 'VARCHAR',
#                         'EmblemHealth HIPaccessI': 'VARCHAR',
#                         'EmblemHealth HIPaccessII': 'VARCHAR',
#                         'EmblemHealth HMO Plus': 'VARCHAR',
#                         'EmblemHealth HMO Preferred Plus': 'VARCHAR',
#                         'EmblemHealth InBalance EPO': 'VARCHAR',
#                         'EmblemHealth Platinum PPO-N (Small Group)': 'VARCHAR',
#                         'EmblemHealth Platinum Premier- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Platinum Value- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth PPO Value (Large Group)': 'VARCHAR',
#                         'EmblemHealth Silver Plus H.S.A (Small Group)': 'VARCHAR',
#                         'EmblemHealth Silver Premier- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Silver Value- P (Small Group)': 'VARCHAR',
#                         'EmblemHealth Vytra HMO (City of NY)': 'VARCHAR',
#                         'Magna Guardian PPO': 'VARCHAR',
#                         'MagnaCare PPO': 'VARCHAR',
#                         'MagnaCare Standard PPO': 'VARCHAR',
#                         'MVP BasiCare PPO': 'VARCHAR',
#                         'MVP HMO': 'VARCHAR',
#                         'MVP Premier': 'VARCHAR',
#                         'MVP Premier Plus': 'VARCHAR',
#                         'MVP Student Health Plan': 'VARCHAR',
#                         'Northwell Direct Commercial Network': 'VARCHAR',
#                         'Aetna Choice POS': 'VARCHAR',
#                         'Aetna Choice POS II': 'VARCHAR',
#                         'Aetna Elect Choice': 'VARCHAR',
#                         'Aetna Health Network Only': 'VARCHAR',
#                         'Aetna Health Network Option': 'VARCHAR',
#                         'Aetna HMO': 'VARCHAR',
#                         'Aetna Limited Benefits Insurance Plan': 'VARCHAR',
#                         'Aetna Managed Choice POS': 'VARCHAR',
#                         'Aetna Meritain PPO': 'VARCHAR',
#                         'Aetna Open Access Aetna Select': 'VARCHAR',
#                         'Aetna Open Access Elect Choice': 'VARCHAR',
#                         'Aetna Open Access HMO': 'VARCHAR',
#                         'Aetna Open Access Managed Choice': 'VARCHAR',
#                         'Aetna Open Choice PPO': 'VARCHAR',
#                         'Aetna Premier Care Network': 'VARCHAR',
#                         'Aetna Quality Point-of-Service (QPOS)': 'VARCHAR',
#                         'Aetna Select': 'VARCHAR',
#                         'Aetna Signature Administrators': 'VARCHAR',
#                         'Aetna Traditional Choice': 'VARCHAR',
#                         'Aetna Value Performance Network': 'VARCHAR',
#                         'Aetna Voluntary Group Medical Plan (Indemnity)': 'VARCHAR',
#                         'Cigna HMO/POS Open Access': 'VARCHAR',
#                         'Cigna Network Open Access': 'VARCHAR',
#                         'Cigna Network/Network POS': 'VARCHAR',
#                         'Cigna Open Access Plus': 'VARCHAR',
#                         'Cigna Open Access Plus/PlusIN Network': 'VARCHAR',
#                         'Cigna Plus Oscar (Cigna+Oscar) LocalPlus': 'VARCHAR',
#                         'Cigna Plus Oscar (Cigna+Oscar) Open Access Plus': 'VARCHAR',
#                         'Cigna PPO/EPO': 'VARCHAR',
#                         'ConnectiCare Bridge EPO': 'VARCHAR',
#                         'ConnectiCare Choice EPO/POS': 'VARCHAR',
#                         'ConnectiCare Choice HMO/POS': 'VARCHAR',
#                         'ConnectiCare Compass Choice EPO': 'VARCHAR',
#                         'ConnectiCare Flex POS': 'VARCHAR',
#                         'ConnectiCare Passage EPO/POS': 'VARCHAR',
#                         'ConnectiCare Passage HMO/POS': 'VARCHAR',
#                         'Connecticare PPO': 'VARCHAR',
#                         'EmblemHealth Bridge ASO': 'VARCHAR',
#                         'EmblemHealth ConsumerDirect PPO': 'VARCHAR',
#                         'EmblemHealth DC37 Med-Team (New York City Plan)': 'VARCHAR',
#                         'EmblemHealth Federal Employee Benefit Plan EPO': 'VARCHAR',
#                         'EmblemHealth GHI CBP Plan (New York City Plan)': 'VARCHAR',
#                         'EmblemHealth GHI HMO (City of NY)': 'VARCHAR',
#                         'EmblemHealth InBalance PPO': 'VARCHAR',
#                         'EmblemHealth Network Access Plan': 'VARCHAR',
#                         'EmblemHealth PPO': 'VARCHAR',
#                         'EmblemHealth PPO Value (EmblemHealth/ConnectiCare Employee Benefit Plan)': 'VARCHAR',
#                         'EmblemHealth PPO Value (Large Group-GHI)': 'VARCHAR',
#                         '1199 SEIU Greater New York Benefit Fund': 'VARCHAR',
#                         '1199 SEIU National Benefit Fund': 'VARCHAR',
#                         '1199 SEIU National Benefit Fund for Home Care Employees': 'VARCHAR',
#                         'Oxford Freedom HMO': 'VARCHAR',
#                         'Oxford Liberty HMO': 'VARCHAR',
#                         'Oxford PPO': 'VARCHAR',
#                         'United HMO': 'VARCHAR',
#                         'United PPO': 'VARCHAR',
#                         'Healthfirst Essential Plan 1': 'VARCHAR',
#                         'Healthfirst Essential Plan 2': 'VARCHAR',
#                         'EmblemHealth Bronze (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Bronze Premier-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Bronze Value-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Catatrophic (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth EPO Value (Large Group-Exch)': 'VARCHAR',
#                         'EmblemHealth EPO Value HDHP (Large Group-Exch)': 'VARCHAR',
#                         'EmblemHealth Gold (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Gold Premier-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Gold Value (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Gold Value-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth HMO Plus (Large Group)': 'VARCHAR',
#                         'EmblemHealth Platinum (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Platinum Premier-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Platinum Value-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth PPO Value (Large Group-Exch)': 'VARCHAR',
#                         'EmblemHealth Silver (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver CSR 1 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver CSR 2 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver CSR 3 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Premier-S (Small Group)': 'VARCHAR',
#                         'EmblemHealth Silver Value (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Value CSR 1 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Value CSR 2 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Value CSR 3 (Individual On/Off Exchange)': 'VARCHAR',
#                         'EmblemHealth Silver Value-S (Small Group)': 'VARCHAR',
#                         'Empire Gold EPO': 'VARCHAR',
#                         'Empire Gold PPO': 'VARCHAR',
#                         'Empire Platinum EPO': 'VARCHAR',
#                         'Empire Platinum PPO': 'VARCHAR',
#                         'Empire Silver EPO': 'VARCHAR',
#                         'Healthfirst Bronze Leaf Plan': 'VARCHAR',
#                         'Healthfirst Bronze Leaf Premier': 'VARCHAR',
#                         'Healthfirst Bronze Pro Plan': 'VARCHAR',
#                         'Healthfirst Bronze Pro Plus Plan': 'VARCHAR',
#                         'Healthfirst Gold Leaf Plan': 'VARCHAR',
#                         'Healthfirst Gold Leaf Premier': 'VARCHAR',
#                         'Healthfirst Gold Pro Plan': 'VARCHAR',
#                         'Healthfirst Gold Pro Plus Plan': 'VARCHAR',
#                         'Healthfirst Green Leaf Plan': 'VARCHAR',
#                         'Healthfirst Platinum Leaf Plan': 'VARCHAR',
#                         'Healthfirst Platinum Leaf Premier': 'VARCHAR',
#                         'Healthfirst Platinum Pro Plan': 'VARCHAR',
#                         'Healthfirst Platinum Pro Plus Plan': 'VARCHAR',
#                         'Healthfirst Silver Leaf Plan': 'VARCHAR',
#                         'Healthfirst Silver Leaf Premier': 'VARCHAR',
#                         'Healthfirst Silver Pro Plan': 'VARCHAR',
#                         'Healthfirst Silver Pro Plus Plan': 'VARCHAR',
#                         'United - Exchange': 'VARCHAR',
#                         'EmblemHealth Essential Plan 1 (BHP)': 'VARCHAR',
#                         'EmblemHealth Essential Plan 1 Plus': 'VARCHAR',
#                         'EmblemHealth Essential Plan 2': 'VARCHAR',
#                         'EmblemHealth Essential Plan 2 Plus': 'VARCHAR',
#                         'Empire Healthplus Essential Plan': 'VARCHAR',
#                         'Fidelis Care Essential Plan 1': 'VARCHAR',
#                         'Fidelis Care Essential Plan 2': 'VARCHAR',
#                         'United - Essential 1&2': 'VARCHAR',
#                         'Fidelis Care Bronze': 'VARCHAR',
#                         'Fidelis Care Catastrophic': 'VARCHAR',
#                         'Fidelis Care Gold ': 'VARCHAR',
#                         'Fidelis Care Platinum': 'VARCHAR',
#                         'Fidelis Care Silver': 'VARCHAR',
#                         'Fidelis Care Silver (100-150)': 'VARCHAR',
#                         'Fidelis Care Silver (150-200)': 'VARCHAR',
#                         'Fidelis Care Silver (200-250)': 'VARCHAR',
#                         'Affinity Child Health Plus': 'VARCHAR',
#                         'Affinity Enriched Plan (HARP)': 'VARCHAR',
#                         'Affinity Medicaid': 'VARCHAR',
#                         'EmblemHealth Enhanced Care': 'VARCHAR',
#                         'EmblemHealth Enhanced Care Plus': 'VARCHAR',
#                         'EmblemHealth Essential Plan 3': 'VARCHAR',
#                         'EmblemHealth Essential Plan 4': 'VARCHAR',
#                         'Empire Healthplus Child Health Plus': 'VARCHAR',
#                         'Empire Healthplus HARP': 'VARCHAR',
#                         'Empire Healthplus Medicaid': 'VARCHAR',
#                         'Empire Healthplus MLTC': 'VARCHAR',
#                         'Fidelis Care at Home (MLTC)': 'VARCHAR',
#                         'Fidelis Care Essential Plan 3': 'VARCHAR',
#                         'Fidelis Care Essential Plan 4': 'VARCHAR',
#                         'Fidelis Child Health Plus': 'VARCHAR',
#                         'Fidelis HealthierLife (HARP)': 'VARCHAR',
#                         'Fidelis Medicaid Managed Care': 'VARCHAR',
#                         'Fidelis Medicaid Managed Care - Restricted': 'VARCHAR',
#                         'Healthfirst Child Health Plus': 'VARCHAR',
#                         'Healthfirst Essential Plan 3': 'VARCHAR',
#                         'Healthfirst Essential Plan 4': 'VARCHAR',
#                         'Healthfirst Medicaid': 'VARCHAR',
#                         'Healthfirst Personal Wellness Plan (PWP) HARP': 'VARCHAR',
#                         'Metroplus Child Health Plus': 'VARCHAR',
#                         'Metroplus HIV Special Needs Plan': 'VARCHAR',
#                         'Metroplus Medicaid': 'VARCHAR',
#                         'United - Essential 3&4': 'VARCHAR',
#                         'United Medicaid': 'VARCHAR',
#                         'Affinity Essential Plan 1-4': 'VARCHAR',
#                         'Metroplus HARP and Essential Plans  1-4': 'VARCHAR',
#                         'Metroplus Exchange': 'VARCHAR',
#                         'Metroplus Gold': 'VARCHAR',
#                         'Metroplus Gold Care 1': 'VARCHAR',
#                         'Metroplus Gold Care 2': 'VARCHAR',
#                         'Aetna Medicare HMO': 'VARCHAR',
#                         'Aetna Medicare Open Access': 'VARCHAR',
#                         'Aetna Medicare PPO': 'VARCHAR',
#                         'EmblemHealth Group Access Rx PPO': 'VARCHAR',
#                         'EmblemHealth VIP Dual (HMO D-SNP)': 'VARCHAR',
#                         'EmblemHealth VIP Dual Select (HMO D-SNP)': 'VARCHAR',
#                         'EmblemHealth VIP Essential (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Go (HMO-POS)': 'VARCHAR',
#                         'EmblemHealth VIP Gold (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Gold Plus (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Part B Saver (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Passport (HMO) ': 'VARCHAR',
#                         'EmblemHealth VIP Passport NYC (HMO) ': 'VARCHAR',
#                         'EmblemHealth VIP Premier (HMO) (Group Plan)': 'VARCHAR',
#                         'EmblemHealth VIP Rx Carve-Out (HMO) (Group Plan)': 'VARCHAR',
#                         'EmblemHealth VIP Rx Saver (HMO)': 'VARCHAR',
#                         'EmblemHealth VIP Solutions (HMO D-SNP)': 'VARCHAR',
#                         'EmblemHealth VIP Value (HMO)': 'VARCHAR',
#                         'Empire MediBlue Access PPO': 'VARCHAR',
#                         'Empire MediBlue Dual Advantage HMO D-SNP': 'VARCHAR',
#                         'Empire MediBlue Dual Advantage Select HMO D-SNP': 'VARCHAR',
#                         'Empire MediBlue Freedom PPO': 'VARCHAR',
#                         'Empire MediBlue HealthPlus Dual Connect': 'VARCHAR',
#                         'Empire MediBlue HealthPlus Dual Plus': 'VARCHAR',
#                         'Empire MediBlue HealthPlus HMO': 'VARCHAR',
#                         'Empire MediBlue HealthPlus Select HMO': 'VARCHAR',
#                         'Empire MediBlue HMO': 'VARCHAR',
#                         'Empire MediBlue HMO (Plus, Service, Choice)': 'VARCHAR',
#                         'Empire MediBlue HMO (Select, Extra Select, Service Select)': 'VARCHAR',
#                         'Empire NYC Medicare Advantage Plus': 'VARCHAR',
#                         'Fidelis Dual Advantage (HMO SNP)': 'VARCHAR',
#                         'Fidelis Dual Advantage Flex (HMO SNP)': 'VARCHAR',
#                         'Fidelis Medicaid Advantage Plus (HMO SNP)': 'VARCHAR',
#                         'Fidelis Medicare Advantage $0 Premium (HMO)': 'VARCHAR',
#                         'Fidelis Medicare Advantage Flex Plan (HMO POS)': 'VARCHAR',
#                         'Fidelis Medicare Advantage Without RX (HMO POS)': 'VARCHAR',
#                         'Healthfirst 65 Plus Plan HMO': 'VARCHAR',
#                         'Healthfirst AbsoluteCare FIDA Plan': 'VARCHAR',
#                         'Healthfirst AssuredCare HMO SNP': 'VARCHAR',
#                         'Healthfirst CompleteCare HMO SNP': 'VARCHAR',
#                         'Healthfirst Coordinated Benefits Plan HMO': 'VARCHAR',
#                         'Healthfirst Increased Benefits Plan HMO': 'VARCHAR',
#                         'Healthfirst Life Improvement Plan HMO SNP': 'VARCHAR',
#                         'Healthfirst Mount Sinai Select HMO': 'VARCHAR',
#                         'Healthfirst Senior Health Partners (SHP)': 'VARCHAR',
#                         'HIP Medicare PPO': 'VARCHAR',
#                         'Humana Medicare HMO': 'VARCHAR',
#                         'Humana Medicare PPO': 'VARCHAR',
#                         'Metroplus FIDA': 'VARCHAR',
#                         'Metroplus Medicare Advantage': 'VARCHAR',
#                         'Oxford Medicare': 'VARCHAR',
#                         'United Medicare': 'VARCHAR',
#                         'Wellcare Medicare Advantage': 'VARCHAR',
#                         'De-identified Maximum': 'VARCHAR',
#                         'De-identified Minimum': 'VARCHAR',
#                         'Discounted Cash Price': 'VARCHAR',
#                        }
# )
# ) TO '/Users/me/data/payless_health/EIN_131624070-lenox-hill-raw.parquet' (COMPRESSION ZSTD);
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT * FROM '/Users/me/data/payless_health/EIN_131624070-lenox-hill-raw.parquet'
# Out:
#         Site Identifier_Code Billing_Code  \
# 0      LENOX                        91038
# 1      LENOX                        91110
# 2      LENOX                        92018
# 3      LENOX                        93454
# 4      LENOX                        93582
# ...      ...             ...          ...
# 53279  LENOX         2602688
# 53280  LENOX         2602691        J9999
# 53281  LENOX         2602692        J9023
# 53282  LENOX         2602694        J3490
# 53283  LENOX         2602698        J9057
#
#                            Identifier_Description    Charge  \
# 0                    Esoph imped funct test > 1hr
# 1                     Gi trc img intral esoph-ile
# 2                        New eye exam & treatment
# 3                       Coronary artery angio s&i
# 4                      Perq transcath closure pda
# ...                                           ...       ...
# 53279              pimozide 1 milliGRAM(s) Tablet      5.56
# ...

# %%
# %%sql
# CREATE TABLE lenox AS SELECT * FROM '/Users/me/data/payless_health/EIN_131624070-lenox-hill-raw.parquet'
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# WITH unpivot_alias AS (
#     UNPIVOT lenox
#     ON COLUMNS(* EXCLUDE ('Site', 'Identifier_Code', 'Billing_Code', 'Identifier_Description'))
#     INTO
#         NAME health_insurance_name
#         VALUE negotiated_rate
# )
# SELECT * FROM unpivot_alias;
# Out:
#            Site Identifier_Code Billing_Code  \
# 0         LENOX                        91038
# 1         LENOX                        91038
# 2         LENOX                        91038
# 3         LENOX                        91038
# 4         LENOX                        91038
# ...         ...             ...          ...
# 13736410  LENOX         2602698        J9057
# 13736411  LENOX         2602698        J9057
# 13736412  LENOX         2602698        J9057
# 13736413  LENOX         2602698        J9057
# 13736414  LENOX         2602698        J9057
#
#                     Identifier_Description         health_insurance_name  \
# 0             Esoph imped funct test > 1hr                        Charge
# 1             Esoph imped funct test > 1hr        Empire Blue Access EPO
# 2             Esoph imped funct test > 1hr        Empire Blue Access PPO
# 3             Esoph imped funct test > 1hr             Empire Bronze EPO
# ...

# %%
# %%sql
# COPY (
# WITH unpivot_alias AS (
#     UNPIVOT lenox
#     ON COLUMNS(* EXCLUDE ('Site', 'Identifier_Code', 'Billing_Code', 'Identifier_Description'))
#     INTO
#         NAME health_insurance_name
#         VALUE negotiated_rate
# )
# SELECT * FROM unpivot_alias
# ) TO '/Users/me/data/payless_health/EIN_131624070-lenox-hill-unpivoted.parquet' (COMPRESSION ZSTD);
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT * FROM '/Users/me/data/payless_health/EIN_131624070-lenox-hill-unpivoted.parquet'
# Out:
#            Site Identifier_Code Billing_Code  \
# 0         LENOX                        91038
# 1         LENOX                        91038
# 2         LENOX                        91038
# 3         LENOX                        91038
# 4         LENOX                        91038
# ...         ...             ...          ...
# 13736410  LENOX         2602698        J9057
# 13736411  LENOX         2602698        J9057
# 13736412  LENOX         2602698        J9057
# 13736413  LENOX         2602698        J9057
# 13736414  LENOX         2602698        J9057
#
#                     Identifier_Description         health_insurance_name  \
# 0             Esoph imped funct test > 1hr                        Charge
# 1             Esoph imped funct test > 1hr        Empire Blue Access EPO
# 2             Esoph imped funct test > 1hr        Empire Blue Access PPO
# 3             Esoph imped funct test > 1hr             Empire Bronze EPO
# ...

# %%
# %%sql
# WITH converted AS (
#   SELECT Billing_Code AS billing_code,
#         Identifier_Description AS description,
#         health_insurance_name,
#         CAST(NULLIF(regexp_replace(negotiated_rate, '[^0-9.]+', '', 'g'), '') AS FLOAT) AS negotiated_rate
#   FROM '/Users/me/data/payless_health/EIN_131624070-lenox-hill-unpivoted.parquet'
# )
# SELECT * FROM converted
# WHERE negotiated_rate IS NOT NULL
# AND negotiated_rate > 0
# AND health_insurance_name != 'Charge'
# AND health_insurance_name != 'De-identified Maximum'
# AND health_insurance_name != 'De-identified Minimum'
# Out:
#         billing_code                       description  \
# 0              91038      Esoph imped funct test > 1hr
# 1              91038      Esoph imped funct test > 1hr
# 2              91038      Esoph imped funct test > 1hr
# 3              91038      Esoph imped funct test > 1hr
# 4              91038      Esoph imped funct test > 1hr
# ...              ...                               ...
# 8789066        J9057  copanlisib 60 mG/4 mL Injectable
# 8789067        J9057  copanlisib 60 mG/4 mL Injectable
# 8789068        J9057  copanlisib 60 mG/4 mL Injectable
# 8789069        J9057  copanlisib 60 mG/4 mL Injectable
# 8789070        J9057  copanlisib 60 mG/4 mL Injectable
#
#                                    health_insurance_name  negotiated_rate
# 0                                 Empire Blue Access EPO      3490.000000
# 1                                 Empire Blue Access PPO      3490.000000
# 2                                      Empire Bronze EPO      3013.000000
# ...

# %%
# %%sql
# COPY (
# WITH converted AS (
#   SELECT Billing_Code AS billing_code,
#         Identifier_Description AS description,
#         health_insurance_name,
#         CAST(NULLIF(regexp_replace(negotiated_rate, '[^0-9.]+', '', 'g'), '') AS FLOAT) AS negotiated_rate
#   FROM '/Users/me/data/payless_health/EIN_131624070-lenox-hill-unpivoted.parquet'
# )
# SELECT * FROM converted
# WHERE negotiated_rate IS NOT NULL
# AND negotiated_rate > 0
# AND health_insurance_name != 'Charge'
# AND health_insurance_name != 'De-identified Maximum'
# AND health_insurance_name != 'De-identified Minimum'
# ) TO '/Users/me/data/payless_health/EIN_131624070-lenox-hill.parquet' (COMPRESSION ZSTD);
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# !cp /Users/me/data/payless_health/EIN_131624070-lenox-hill.parquet /Users/me/projects/payless.health/docs/public/data/
